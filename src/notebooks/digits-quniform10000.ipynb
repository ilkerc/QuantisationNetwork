# %%
# %matplotlib inline
import os
import time
# os.environ['THEANO_FLAGS']='contexts=dev0->cuda0;dev1->cuda1'
os.environ['THEANO_FLAGS']='device=gpu0'
import theano
import lasagne
import numpy as np
import cPickle as pickle
import theano.tensor as T
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits as load_sk_dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
from lasagne.layers import InputLayer, DenseLayer, DropoutLayer
from helpers.DiscreteLayer import DiscreteLayer
# Out:
# Using gpu device 0: GeForce GTX 1070 (CNMeM is enabled with initial size: 40.0% of memory, cuDNN 5005)

# %% [markdown]
# # Breast Cancer dataset cl
# * 30 Dimensions of Features
# * 2 Classes
# * 569 examples (212(M),357(B))
#
# I'll be using ML.Perceptron, for classification

# %%
# Constants
NUM_EPOCHS = 500
BATCH_SIZE = 10
LEARNING_RATE = 0.001

# Disc. Layer Settings
DISC = True
QUANT_UNIT = 5
QUANT = np.array(np.repeat(0.125, QUANT_UNIT), dtype='float32')
VARIANCE_DEVIDER = 50000.0
ADDITIONAL_COST = False
# Uniform Settings
UNIFORM_QUANT = True
UNIFORM_STEP = 10000

# Test Specs
TEST_NAME = 'digits-quniform10000'

# Additional Settings
lasagne.random.set_rng(np.random.RandomState(12345))  # Set random state so we can investigate results
np.random.seed(1234)
#theano.config.exception_verbosity = 'high'

# %%
def load_dataset():
    dataset = load_sk_dataset()
    X = dataset['data']
    no_classes = len(np.unique(dataset['target']))
    X = normalize(X, norm='l2')
    #     X = (X - X.mean()) / X.std()
    Y = dataset['target']
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=41)
    return dict(X_train=X_train,
               y_train=y_train,
               X_test=X_test,
               y_test=y_test,
               classes=no_classes)
data = load_dataset()
NUM_CLASSES = data['classes']

# %%
def build_mlp(Xs, disc, classnum, QUANT_UNIT):
    tanh = lasagne.nonlinearities.tanh
    softmax = lasagne.nonlinearities.softmax
    
    l_in = InputLayer(shape=Xs.shape)
    l_dense1 = DenseLayer(l_in, num_units=25, nonlinearity=tanh)
    l_dense2 = DenseLayer(l_dense1, num_units=QUANT_UNIT, nonlinearity=tanh, name='param_regressor')
    if disc:
        sharedBins = theano.shared(None, name='sharedBins')
        l_dis = DiscreteLayer(l_dense2, sharedBins=sharedBins, name='disclayer')
        print("Using Discret. Layer")
    else:
        l_dis = l_dense2
        print("No Disc. Layer")
    l_class = DenseLayer(l_dis, num_units=classnum, nonlinearity=softmax)
    
    if disc:
        return l_class, sharedBins
    else:
        return l_class

if DISC:
    model, sharedBins = build_mlp(data['X_train'], disc=DISC, classnum=NUM_CLASSES, QUANT_UNIT=QUANT_UNIT)
else:
    model = build_mlp(data['X_train'], disc=DISC, classnum=NUM_CLASSES, QUANT_UNIT=QUANT_UNIT)
model_params = lasagne.layers.get_all_params(model, trainable=True)
# Out:
# Using Discret. Layer

# %%
"""
Input: dist, dist.shape = (-1, num_units)
Find quantization bins of a given dist history
Returns a list of (x, num_units), where x's length is a random variable
"""
def find_quantization_bins(dist, sharedBins):
    # Quantizer function
    def Q(x, y):
        return y * np.floor((x/y) + .5)
    
    shape = dist.shape
    init_Q = QUANT
    final_Q = []
    
    # If Uniform Quantization
    if UNIFORM_QUANT:
        uniform_bin = np.linspace(-1, 1, UNIFORM_STEP)
        uniform_bins = np.tile(uniform_bin, (shape[0], 1))
        sharedBins.set_value(uniform_bins)
        print "Uniform Quantization"
        return uniform_bins
    
    # Theta iterator
    for i in range(shape[1]):
        theta_i = dist[:, i]
        
        # Whats is the error threshold for this distribution
        Q_eps = np.var(theta_i) / VARIANCE_DEVIDER
        
        # Batch Iterator
        final_Q_i = []
        for j in range(shape[0]):
            theta = theta_i[j]
            
            # Quantized theta = Quantization bins
            q = init_Q[i]
            x_i = theta
            x_o = Q(x_i, q)
            
            # Optimize x_o

            while(np.abs(x_o - x_i) > Q_eps):
                q = q / 2
                x_o = Q(x_i, q)
            
            # End of optimisation
            final_Q_i.append(x_o)
        
        # Append to outer list
        uniques = np.unique(np.array(final_Q_i))
        final_Q.append(uniques.astype(theano.config.floatX))
        
    # Report
    print "New Bin Sizes: [" + ", ".join([str(final_Q[x].shape[0]) for x in range(shape[1])] ) + "]"
    sharedBins.set_value(final_Q)
    return final_Q

# %%
def build_functions():
    X = T.matrix(dtype=theano.config.floatX)
    y = T.ivector()

    ## Layer History
    if DISC:
        l_disc = next(l for l in lasagne.layers.get_all_layers(model) if l.name is 'disclayer')
        l_paramreg = next(l for l in lasagne.layers.get_all_layers(model) if l.name is 'param_regressor')
        l_disc_output, l_paramreg_output = lasagne.layers.get_output([l_disc, l_paramreg], X, deterministic=False)
    ## Layer History

    # training output
    output_train = lasagne.layers.get_output(model, X, deterministic=False)

    # evaluation output. Also includes output of transform for plotting
    output_eval = lasagne.layers.get_output(model, X, deterministic=True)

    sh_lr = theano.shared(lasagne.utils.floatX(LEARNING_RATE))
    cost = T.mean(T.nnet.categorical_crossentropy(output_train, y))
    
    if ADDITIONAL_COST and DISC:
        cost += T.mean(lasagne.objectives.squared_error(l_disc_output, l_paramreg_output))
    
    updates = lasagne.updates.adam(cost, model_params, learning_rate=sh_lr)
    
    # updates = lasagne.updates.nesterov_momentum(cost, model_params, learning_rate=0.01, momentum=0.9)

    if DISC:
        train = theano.function([X, y], [cost, output_train, l_disc_output, l_paramreg_output], updates=updates, allow_input_downcast=True)
    else:
        train = theano.function([X, y], [cost, output_train], updates=updates, allow_input_downcast=True)
    eval = theano.function([X], [output_eval], allow_input_downcast=True)
    
    return train, eval, sh_lr

train, eval, sh_lr = build_functions()

# %%
def train_epoch(X, y):
    # History Keeping
    param_output = []
    disc_output = []
    # History
    num_samples = X.shape[0]
    num_batches = int(np.ceil(num_samples / float(BATCH_SIZE)))
    costs = []
    correct = 0
    for i in range(num_batches):
        idx = range(i*BATCH_SIZE, np.minimum((i+1)*BATCH_SIZE, num_samples))
        X_batch = X[idx]
        y_batch = y[idx]
        if DISC:
            cost, output_train, l_disc_output, l_paramreg_output = train(X_batch, y_batch)
            param_output = np.append(param_output, l_paramreg_output)
            disc_output = np.append(disc_output, l_disc_output)
        else:
            cost, output_train = train(X_batch, y_batch)
        costs += [cost]
        preds = np.argmax(output_train, axis=-1)
        correct += np.sum(y_batch == preds)
    
    return np.mean(costs), correct / float(num_samples), param_output, disc_output


def eval_epoch(X, y):
    output_eval = eval(X)
    preds = np.argmax(output_eval, axis=-1)
    acc = np.mean(preds == y)
    return acc

# %%
np.set_printoptions(formatter={'float': '{: 0.4f}'.format}, suppress=True)
train_accs, test_accs = [], []
total_time = 0
param_outputs, disc_outputs = [], []
disc_dist_t_1 = None
quantized_bins = []
try:
    for n in range(NUM_EPOCHS):
        start_time = time.time()
        train_cost, train_acc, param_output, disc_output = train_epoch(data['X_train'], data['y_train'])
        test_acc = eval_epoch(data['X_test'], data['y_test'])
        test_accs += [test_acc]
        train_accs += [train_acc]

        if DISC:
            param_outputs = np.append(param_outputs, param_output)
            disc_outputs = np.append(disc_outputs, disc_output)

        if (n+1) % 20 == 0:
            new_lr = sh_lr.get_value() * 0.90
            print "New LR:", new_lr
            sh_lr.set_value(lasagne.utils.floatX(new_lr))
        
        # Non-uniform Quantization
        if DISC:
            if n>0 and np.mod(n, 10) == 0:
                dist = disc_output.reshape((-1, QUANT_UNIT))
                q_bins = find_quantization_bins(dist, sharedBins=sharedBins)
                quantized_bins.append(q_bins)

        time_spent = time.time() - start_time
        total_time += time_spent
        print "Epoch {0}: T.cost {1:0.6f}, Train acc {2:0.6f}, test acc {3:0.6f}, took {4:.3} sec.".format(
                n, train_cost, train_acc, test_acc, time_spent)

except KeyboardInterrupt:
    pass
print "\nTotal time spent: {0:.5} seconds\nTraing Acc: {1}\nTest Acc: {2}\n".format(total_time, train_acc, test_acc) 

if DISC:
    story = {'train_accs': train_accs,
             'test_accs': test_accs,
             'epoch_reached': n, 
             'total_time': total_time,
             'disc_enabled': DISC,
             'learning_rate': LEARNING_RATE,
             'batch_size': BATCH_SIZE,
             'dense_params': param_output,
             'disc_params': disc_output,
             'quantized_bins': quantized_bins}
else:
    story = {'train_accs': train_accs,
             'test_accs': test_accs,
             'epoch_reached': n, 
             'total_time': total_time,
             'disc_enabled': DISC,
             'learning_rate': LEARNING_RATE,
             'batch_size': BATCH_SIZE,
             'disc_params': disc_output}   

with open(TEST_NAME + '.model', 'wb') as fp:
  pickle.dump(story, fp)
# Out:
# Epoch 0: T.cost 2.193990, Train acc 0.265136, test acc 0.402778, took 0.0914 sec.
# Epoch 1: T.cost 1.905052, Train acc 0.463466, test acc 0.472222, took 0.096 sec.
# Epoch 2: T.cost 1.581611, Train acc 0.543493, test acc 0.575000, took 0.0936 sec.
# Epoch 3: T.cost 1.344940, Train acc 0.620042, test acc 0.644444, took 0.0862 sec.
# Epoch 4: T.cost 1.187123, Train acc 0.654141, test acc 0.663889, took 0.0815 sec.
# Epoch 5: T.cost 1.073210, Train acc 0.672930, test acc 0.672222, took 0.0812 sec.
# Epoch 6: T.cost 0.983326, Train acc 0.703549, test acc 0.700000, took 0.0821 sec.
# Epoch 7: T.cost 0.908940, Train acc 0.736952, test acc 0.722222, took 0.0813 sec.
# Epoch 8: T.cost 0.845830, Train acc 0.768267, test acc 0.744444, took 0.0792 sec.
# Epoch 9: T.cost 0.791274, Train acc 0.789840, test acc 0.769444, took 0.0815 sec.
# Uniform Quantization
# Epoch 10: T.cost 0.743539, Train acc 0.798887, test acc 0.780556, took 0.16 sec.
# helpers/Quantizer.py:26: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if sharedBins == None:
# Epoch 11: T.cost 0.701574, Train acc 0.815588, test acc 0.783333, took 8.63 sec.
# Epoch 12: T.cost 0.664598, Train acc 0.826722, test acc 0.791667, took 8.37 sec.
# Epoch 13: T.cost 0.631827, Train acc 0.832985, test acc 0.805556, took 8.8 sec.
# Epoch 14: T.cost 0.602491, Train acc 0.839944, test acc 0.816667, took 8.8 sec.
# Epoch 15: T.cost 0.575870, Train acc 0.846207, test acc 0.822222, took 8.51 sec.
# Epoch 16: T.cost 0.551369, Train acc 0.853862, test acc 0.836111, took 8.57 sec.
# Epoch 17: T.cost 0.528475, Train acc 0.859429, test acc 0.847222, took 8.47 sec.
# Epoch 18: T.cost 0.506789, Train acc 0.867780, test acc 0.855556, took 8.53 sec.
# New LR: 0.000900000042748
# Epoch 19: T.cost 0.485986, Train acc 0.869172, test acc 0.872222, took 8.51 sec.
# Uniform Quantization
# Epoch 20: T.cost 0.466749, Train acc 0.878219, test acc 0.880556, took 8.5 sec.
# Epoch 21: T.cost 0.448801, Train acc 0.883090, test acc 0.880556, took 8.7 sec.
# Epoch 22: T.cost 0.431509, Train acc 0.890049, test acc 0.886111, took 8.56 sec.
# Epoch 23: T.cost 0.414675, Train acc 0.894920, test acc 0.891667, took 8.75 sec.
# Epoch 24: T.cost 0.398339, Train acc 0.901879, test acc 0.900000, took 9.1 sec.
# Epoch 25: T.cost 0.382544, Train acc 0.904662, test acc 0.900000, took 8.78 sec.
# Epoch 26: T.cost 0.367342, Train acc 0.910230, test acc 0.905556, took 8.74 sec.
# Epoch 27: T.cost 0.352754, Train acc 0.915797, test acc 0.908333, took 8.63 sec.
# Epoch 28: T.cost 0.338821, Train acc 0.920668, test acc 0.916667, took 8.72 sec.
# Epoch 29: T.cost 0.325581, Train acc 0.929019, test acc 0.916667, took 8.86 sec.
# Uniform Quantization
# Epoch 30: T.cost 0.313055, Train acc 0.933194, test acc 0.922222, took 8.2 sec.
# Epoch 31: T.cost 0.301257, Train acc 0.936674, test acc 0.925000, took 8.14 sec.
# Epoch 32: T.cost 0.290183, Train acc 0.940849, test acc 0.925000, took 8.17 sec.
# Epoch 33: T.cost 0.279808, Train acc 0.944328, test acc 0.927778, took 8.22 sec.
# Epoch 34: T.cost 0.270100, Train acc 0.945720, test acc 0.927778, took 8.17 sec.
# Epoch 35: T.cost 0.261026, Train acc 0.946416, test acc 0.930556, took 8.2 sec.
# Epoch 36: T.cost 0.252534, Train acc 0.947808, test acc 0.933333, took 8.23 sec.
# Epoch 37: T.cost 0.244587, Train acc 0.949200, test acc 0.933333, took 8.16 sec.
# Epoch 38: T.cost 0.237139, Train acc 0.949896, test acc 0.933333, took 8.09 sec.
# New LR: 0.000810000038473
# Epoch 39: T.cost 0.230147, Train acc 0.950592, test acc 0.933333, took 8.09 sec.
# Uniform Quantization
# Epoch 40: T.cost 0.223510, Train acc 0.954071, test acc 0.933333, took 8.19 sec.
# Epoch 41: T.cost 0.217641, Train acc 0.955463, test acc 0.933333, took 8.19 sec.
# Epoch 42: T.cost 0.212267, Train acc 0.956159, test acc 0.936111, took 8.57 sec.
# Epoch 43: T.cost 0.207168, Train acc 0.957550, test acc 0.936111, took 8.48 sec.
# Epoch 44: T.cost 0.202321, Train acc 0.957550, test acc 0.936111, took 8.43 sec.
# Epoch 45: T.cost 0.197705, Train acc 0.959638, test acc 0.936111, took 8.47 sec.
# Epoch 46: T.cost 0.193299, Train acc 0.959638, test acc 0.938889, took 8.37 sec.
# Epoch 47: T.cost 0.189100, Train acc 0.959638, test acc 0.936111, took 8.37 sec.
# Epoch 48: T.cost 0.185086, Train acc 0.960334, test acc 0.936111, took 8.38 sec.
# Epoch 49: T.cost 0.181248, Train acc 0.961030, test acc 0.936111, took 8.24 sec.
# Uniform Quantization
# Epoch 50: T.cost 0.177584, Train acc 0.961726, test acc 0.933333, took 8.46 sec.
# Epoch 51: T.cost 0.174078, Train acc 0.961726, test acc 0.933333, took 8.36 sec.
# Epoch 52: T.cost 0.170731, Train acc 0.962422, test acc 0.933333, took 8.32 sec.
# Epoch 53: T.cost 0.167525, Train acc 0.962422, test acc 0.933333, took 8.41 sec.
# Epoch 54: T.cost 0.164460, Train acc 0.963814, test acc 0.936111, took 8.43 sec.
# Epoch 55: T.cost 0.161527, Train acc 0.965205, test acc 0.936111, took 8.36 sec.
# Epoch 56: T.cost 0.158717, Train acc 0.965901, test acc 0.936111, took 8.5 sec.
# Epoch 57: T.cost 0.156020, Train acc 0.966597, test acc 0.936111, took 8.44 sec.
# Epoch 58: T.cost 0.153431, Train acc 0.967989, test acc 0.936111, took 8.49 sec.
# New LR: 0.000729000050342
# Epoch 59: T.cost 0.150948, Train acc 0.969381, test acc 0.936111, took 8.51 sec.
# Uniform Quantization
# Epoch 60: T.cost 0.148124, Train acc 0.970077, test acc 0.936111, took 8.69 sec.
# Epoch 61: T.cost 0.145951, Train acc 0.970772, test acc 0.933333, took 8.57 sec.
# Epoch 62: T.cost 0.143924, Train acc 0.970772, test acc 0.933333, took 8.49 sec.
# Epoch 63: T.cost 0.141978, Train acc 0.970772, test acc 0.933333, took 8.54 sec.
# Epoch 64: T.cost 0.140105, Train acc 0.972164, test acc 0.933333, took 8.43 sec.
# Epoch 65: T.cost 0.138299, Train acc 0.972164, test acc 0.933333, took 8.46 sec.
# Epoch 66: T.cost 0.136558, Train acc 0.972164, test acc 0.933333, took 8.38 sec.
# Epoch 67: T.cost 0.134881, Train acc 0.972164, test acc 0.933333, took 8.47 sec.
# Epoch 68: T.cost 0.133254, Train acc 0.972164, test acc 0.933333, took 8.41 sec.
# Epoch 69: T.cost 0.131683, Train acc 0.972860, test acc 0.933333, took 8.43 sec.
# Uniform Quantization
# Epoch 70: T.cost 0.130161, Train acc 0.972164, test acc 0.933333, took 8.51 sec.
# Epoch 71: T.cost 0.128686, Train acc 0.972164, test acc 0.936111, took 8.5 sec.
# Epoch 72: T.cost 0.127250, Train acc 0.972164, test acc 0.936111, took 8.53 sec.
# Epoch 73: T.cost 0.125856, Train acc 0.972860, test acc 0.938889, took 8.5 sec.
# Epoch 74: T.cost 0.124500, Train acc 0.972860, test acc 0.938889, took 8.66 sec.
# Epoch 75: T.cost 0.123178, Train acc 0.972860, test acc 0.938889, took 8.68 sec.
# Epoch 76: T.cost 0.121887, Train acc 0.972860, test acc 0.938889, took 8.58 sec.
# Epoch 77: T.cost 0.120630, Train acc 0.972860, test acc 0.938889, took 8.56 sec.
# Epoch 78: T.cost 0.119400, Train acc 0.972860, test acc 0.941667, took 8.67 sec.
# New LR: 0.000656100071501
# Epoch 79: T.cost 0.118194, Train acc 0.973556, test acc 0.941667, took 8.55 sec.
# Uniform Quantization
# Epoch 80: T.cost 0.116516, Train acc 0.974948, test acc 0.941667, took 8.62 sec.
# Epoch 81: T.cost 0.115431, Train acc 0.974948, test acc 0.941667, took 8.45 sec.
# Epoch 82: T.cost 0.114388, Train acc 0.974948, test acc 0.941667, took 8.52 sec.
# Epoch 83: T.cost 0.113371, Train acc 0.974948, test acc 0.941667, took 8.52 sec.
# Epoch 84: T.cost 0.112379, Train acc 0.974948, test acc 0.944444, took 8.41 sec.
# Epoch 85: T.cost 0.111399, Train acc 0.974948, test acc 0.944444, took 8.42 sec.
# Epoch 86: T.cost 0.110442, Train acc 0.974948, test acc 0.944444, took 8.4 sec.
# Epoch 87: T.cost 0.109502, Train acc 0.975644, test acc 0.944444, took 8.43 sec.
# Epoch 88: T.cost 0.108579, Train acc 0.976340, test acc 0.944444, took 8.47 sec.
# Epoch 89: T.cost 0.107671, Train acc 0.976340, test acc 0.944444, took 8.48 sec.
# Uniform Quantization
# Epoch 90: T.cost 0.106780, Train acc 0.976340, test acc 0.944444, took 8.56 sec.
# Epoch 91: T.cost 0.105905, Train acc 0.976340, test acc 0.947222, took 8.41 sec.
# Epoch 92: T.cost 0.105042, Train acc 0.976340, test acc 0.947222, took 8.43 sec.
# Epoch 93: T.cost 0.104198, Train acc 0.976340, test acc 0.947222, took 8.42 sec.
# Epoch 94: T.cost 0.103363, Train acc 0.976340, test acc 0.950000, took 8.44 sec.
# Epoch 95: T.cost 0.102545, Train acc 0.976340, test acc 0.950000, took 8.54 sec.
# Epoch 96: T.cost 0.101739, Train acc 0.976340, test acc 0.950000, took 8.51 sec.
# Epoch 97: T.cost 0.100945, Train acc 0.977035, test acc 0.950000, took 8.53 sec.
# Epoch 98: T.cost 0.100162, Train acc 0.977731, test acc 0.950000, took 8.47 sec.
# New LR: 0.000590490043396
# Epoch 99: T.cost 0.099394, Train acc 0.977731, test acc 0.950000, took 8.46 sec.
# Uniform Quantization
# Epoch 100: T.cost 0.098183, Train acc 0.978427, test acc 0.950000, took 8.67 sec.
# Epoch 101: T.cost 0.097469, Train acc 0.978427, test acc 0.950000, took 8.25 sec.
# Epoch 102: T.cost 0.096787, Train acc 0.979819, test acc 0.950000, took 8.3 sec.
# Epoch 103: T.cost 0.096115, Train acc 0.980515, test acc 0.950000, took 8.35 sec.
# Epoch 104: T.cost 0.095454, Train acc 0.980515, test acc 0.950000, took 8.36 sec.
# Epoch 105: T.cost 0.094804, Train acc 0.980515, test acc 0.950000, took 8.31 sec.
# Epoch 106: T.cost 0.094160, Train acc 0.980515, test acc 0.950000, took 8.28 sec.
# Epoch 107: T.cost 0.093530, Train acc 0.980515, test acc 0.952778, took 8.42 sec.
# Epoch 108: T.cost 0.092900, Train acc 0.980515, test acc 0.952778, took 8.37 sec.
# Epoch 109: T.cost 0.092283, Train acc 0.981211, test acc 0.952778, took 8.18 sec.
# Uniform Quantization
# Epoch 110: T.cost 0.091670, Train acc 0.981211, test acc 0.952778, took 8.57 sec.
# Epoch 111: T.cost 0.091063, Train acc 0.981211, test acc 0.952778, took 8.29 sec.
# Epoch 112: T.cost 0.090460, Train acc 0.981211, test acc 0.952778, took 8.44 sec.
# Epoch 113: T.cost 0.089865, Train acc 0.981211, test acc 0.952778, took 8.38 sec.
# Epoch 114: T.cost 0.089275, Train acc 0.981211, test acc 0.952778, took 8.48 sec.
# Epoch 115: T.cost 0.088689, Train acc 0.981211, test acc 0.952778, took 8.32 sec.
# Epoch 116: T.cost 0.088108, Train acc 0.981907, test acc 0.952778, took 8.3 sec.
# Epoch 117: T.cost 0.087531, Train acc 0.981907, test acc 0.952778, took 8.49 sec.
# Epoch 118: T.cost 0.086960, Train acc 0.981907, test acc 0.952778, took 8.49 sec.
# New LR: 0.000531441054773
# Epoch 119: T.cost 0.086394, Train acc 0.982603, test acc 0.952778, took 8.56 sec.
# Uniform Quantization
# Epoch 120: T.cost 0.085425, Train acc 0.982603, test acc 0.952778, took 8.66 sec.
# Epoch 121: T.cost 0.084874, Train acc 0.983299, test acc 0.952778, took 8.61 sec.
# Epoch 122: T.cost 0.084352, Train acc 0.983299, test acc 0.952778, took 8.62 sec.
# Epoch 123: T.cost 0.083836, Train acc 0.983994, test acc 0.952778, took 8.55 sec.
# Epoch 124: T.cost 0.083324, Train acc 0.983994, test acc 0.952778, took 8.61 sec.
# Epoch 125: T.cost 0.082818, Train acc 0.983994, test acc 0.952778, took 8.59 sec.
# Epoch 126: T.cost 0.082312, Train acc 0.983994, test acc 0.952778, took 8.68 sec.
# Epoch 127: T.cost 0.081808, Train acc 0.983994, test acc 0.952778, took 8.59 sec.
# Epoch 128: T.cost 0.081306, Train acc 0.984690, test acc 0.952778, took 8.63 sec.
# Epoch 129: T.cost 0.080805, Train acc 0.984690, test acc 0.952778, took 8.56 sec.
# Uniform Quantization
# Epoch 130: T.cost 0.080307, Train acc 0.985386, test acc 0.952778, took 8.79 sec.
# Epoch 131: T.cost 0.079805, Train acc 0.985386, test acc 0.952778, took 8.76 sec.
# Epoch 132: T.cost 0.079307, Train acc 0.985386, test acc 0.952778, took 8.82 sec.
# Epoch 133: T.cost 0.078812, Train acc 0.986082, test acc 0.952778, took 8.8 sec.
# Epoch 134: T.cost 0.078312, Train acc 0.986082, test acc 0.952778, took 8.77 sec.
# Epoch 135: T.cost 0.077815, Train acc 0.986082, test acc 0.952778, took 8.66 sec.
# Epoch 136: T.cost 0.077320, Train acc 0.987474, test acc 0.952778, took 8.66 sec.
# Epoch 137: T.cost 0.076827, Train acc 0.987474, test acc 0.952778, took 8.76 sec.
# Epoch 138: T.cost 0.076333, Train acc 0.987474, test acc 0.952778, took 8.8 sec.
# New LR: 0.000478296959773
# Epoch 139: T.cost 0.075842, Train acc 0.987474, test acc 0.952778, took 8.68 sec.
# Uniform Quantization
# Epoch 140: T.cost 0.074978, Train acc 0.987474, test acc 0.950000, took 8.85 sec.
# Epoch 141: T.cost 0.074487, Train acc 0.987474, test acc 0.952778, took 8.69 sec.
# Epoch 142: T.cost 0.074037, Train acc 0.987474, test acc 0.955556, took 8.66 sec.
# Epoch 143: T.cost 0.073598, Train acc 0.987474, test acc 0.955556, took 8.6 sec.
# Epoch 144: T.cost 0.073157, Train acc 0.987474, test acc 0.955556, took 8.55 sec.
# Epoch 145: T.cost 0.072720, Train acc 0.987474, test acc 0.955556, took 8.62 sec.
# Epoch 146: T.cost 0.072288, Train acc 0.987474, test acc 0.955556, took 8.59 sec.
# Epoch 147: T.cost 0.071857, Train acc 0.987474, test acc 0.955556, took 8.6 sec.
# Epoch 148: T.cost 0.071430, Train acc 0.987474, test acc 0.955556, took 8.51 sec.
# Epoch 149: T.cost 0.071004, Train acc 0.987474, test acc 0.955556, took 8.36 sec.
# Uniform Quantization
# Epoch 150: T.cost 0.070581, Train acc 0.987474, test acc 0.955556, took 8.64 sec.
# Epoch 151: T.cost 0.070162, Train acc 0.987474, test acc 0.955556, took 8.81 sec.
# Epoch 152: T.cost 0.069743, Train acc 0.987474, test acc 0.955556, took 8.49 sec.
# Epoch 153: T.cost 0.069326, Train acc 0.987474, test acc 0.955556, took 8.65 sec.
# Epoch 154: T.cost 0.068910, Train acc 0.987474, test acc 0.955556, took 8.35 sec.
# Epoch 155: T.cost 0.068496, Train acc 0.987474, test acc 0.955556, took 8.26 sec.
# Epoch 156: T.cost 0.068087, Train acc 0.988170, test acc 0.955556, took 8.43 sec.
# Epoch 157: T.cost 0.067674, Train acc 0.988170, test acc 0.955556, took 8.31 sec.
# Epoch 158: T.cost 0.067265, Train acc 0.988170, test acc 0.955556, took 8.14 sec.
# New LR: 0.000430467253318
# Epoch 159: T.cost 0.066859, Train acc 0.988170, test acc 0.955556, took 8.17 sec.
# Uniform Quantization
# Epoch 160: T.cost 0.066122, Train acc 0.988170, test acc 0.952778, took 8.36 sec.
# Epoch 161: T.cost 0.065713, Train acc 0.988170, test acc 0.955556, took 8.21 sec.
# Epoch 162: T.cost 0.065343, Train acc 0.988170, test acc 0.955556, took 8.13 sec.
# Epoch 163: T.cost 0.064977, Train acc 0.988170, test acc 0.955556, took 8.4 sec.
# Epoch 164: T.cost 0.064613, Train acc 0.988866, test acc 0.952778, took 8.44 sec.
# Epoch 165: T.cost 0.064253, Train acc 0.988866, test acc 0.950000, took 8.32 sec.
# Epoch 166: T.cost 0.063893, Train acc 0.988866, test acc 0.950000, took 8.13 sec.
# Epoch 167: T.cost 0.063533, Train acc 0.988866, test acc 0.950000, took 8.2 sec.
# Epoch 168: T.cost 0.063180, Train acc 0.988866, test acc 0.950000, took 8.41 sec.
# Epoch 169: T.cost 0.062823, Train acc 0.988866, test acc 0.947222, took 8.39 sec.
# Uniform Quantization
# Epoch 170: T.cost 0.062467, Train acc 0.988866, test acc 0.947222, took 8.28 sec.
# Epoch 171: T.cost 0.062116, Train acc 0.988866, test acc 0.947222, took 8.41 sec.
# Epoch 172: T.cost 0.061764, Train acc 0.988866, test acc 0.947222, took 8.23 sec.
# Epoch 173: T.cost 0.061414, Train acc 0.988866, test acc 0.947222, took 8.25 sec.
# Epoch 174: T.cost 0.061066, Train acc 0.989562, test acc 0.947222, took 8.23 sec.
# Epoch 175: T.cost 0.060716, Train acc 0.989562, test acc 0.947222, took 8.39 sec.
# Epoch 176: T.cost 0.060373, Train acc 0.989562, test acc 0.947222, took 8.14 sec.
# Epoch 177: T.cost 0.060027, Train acc 0.989562, test acc 0.947222, took 8.09 sec.
# Epoch 178: T.cost 0.059685, Train acc 0.989562, test acc 0.947222, took 8.23 sec.
# New LR: 0.000387420522748
# Epoch 179: T.cost 0.059345, Train acc 0.989562, test acc 0.947222, took 8.2 sec.
# Uniform Quantization
# Epoch 180: T.cost 0.058727, Train acc 0.989562, test acc 0.947222, took 8.28 sec.
# Epoch 181: T.cost 0.058388, Train acc 0.989562, test acc 0.947222, took 8.43 sec.
# Epoch 182: T.cost 0.058080, Train acc 0.989562, test acc 0.947222, took 8.4 sec.
# Epoch 183: T.cost 0.057779, Train acc 0.989562, test acc 0.947222, took 8.44 sec.
# Epoch 184: T.cost 0.057480, Train acc 0.989562, test acc 0.947222, took 8.31 sec.
# Epoch 185: T.cost 0.057182, Train acc 0.989562, test acc 0.947222, took 8.21 sec.
# Epoch 186: T.cost 0.056884, Train acc 0.990257, test acc 0.947222, took 8.21 sec.
# Epoch 187: T.cost 0.056591, Train acc 0.990953, test acc 0.947222, took 8.18 sec.
# Epoch 188: T.cost 0.056296, Train acc 0.990953, test acc 0.947222, took 8.22 sec.
# Epoch 189: T.cost 0.056006, Train acc 0.990953, test acc 0.947222, took 8.48 sec.
# Uniform Quantization
# Epoch 190: T.cost 0.055713, Train acc 0.990953, test acc 0.947222, took 8.44 sec.
# Epoch 191: T.cost 0.055425, Train acc 0.990953, test acc 0.947222, took 8.14 sec.
# Epoch 192: T.cost 0.055138, Train acc 0.990953, test acc 0.947222, took 8.22 sec.
# Epoch 193: T.cost 0.054850, Train acc 0.991649, test acc 0.947222, took 8.34 sec.
# Epoch 194: T.cost 0.054565, Train acc 0.991649, test acc 0.947222, took 8.25 sec.
# Epoch 195: T.cost 0.054281, Train acc 0.991649, test acc 0.947222, took 8.11 sec.
# Epoch 196: T.cost 0.053999, Train acc 0.992345, test acc 0.947222, took 8.13 sec.
# Epoch 197: T.cost 0.053718, Train acc 0.992345, test acc 0.947222, took 8.15 sec.
# Epoch 198: T.cost 0.053439, Train acc 0.992345, test acc 0.947222, took 8.15 sec.
# New LR: 0.000348678475711
# Epoch 199: T.cost 0.053163, Train acc 0.992345, test acc 0.947222, took 8.22 sec.
# Uniform Quantization
# Epoch 200: T.cost 0.052667, Train acc 0.992345, test acc 0.947222, took 8.23 sec.
# Epoch 201: T.cost 0.052393, Train acc 0.992345, test acc 0.947222, took 8.14 sec.
# Epoch 202: T.cost 0.052145, Train acc 0.992345, test acc 0.950000, took 8.12 sec.
# Epoch 203: T.cost 0.051899, Train acc 0.992345, test acc 0.950000, took 8.06 sec.
# Epoch 204: T.cost 0.051655, Train acc 0.992345, test acc 0.950000, took 8.1 sec.
# Epoch 205: T.cost 0.051413, Train acc 0.992345, test acc 0.950000, took 8.1 sec.
# Epoch 206: T.cost 0.051170, Train acc 0.992345, test acc 0.950000, took 8.11 sec.
# Epoch 207: T.cost 0.050932, Train acc 0.992345, test acc 0.950000, took 8.11 sec.
# Epoch 208: T.cost 0.050692, Train acc 0.992345, test acc 0.950000, took 8.11 sec.
# Epoch 209: T.cost 0.050455, Train acc 0.992345, test acc 0.950000, took 8.14 sec.
# Uniform Quantization
# Epoch 210: T.cost 0.050219, Train acc 0.992345, test acc 0.950000, took 8.21 sec.
# Epoch 211: T.cost 0.049982, Train acc 0.992345, test acc 0.950000, took 8.14 sec.
# Epoch 212: T.cost 0.049747, Train acc 0.992345, test acc 0.950000, took 8.15 sec.
# Epoch 213: T.cost 0.049513, Train acc 0.992345, test acc 0.950000, took 8.14 sec.
# Epoch 214: T.cost 0.049281, Train acc 0.992345, test acc 0.950000, took 8.09 sec.
# Epoch 215: T.cost 0.049050, Train acc 0.992345, test acc 0.950000, took 8.12 sec.
# Epoch 216: T.cost 0.048820, Train acc 0.992345, test acc 0.950000, took 8.13 sec.
# Epoch 217: T.cost 0.048591, Train acc 0.992345, test acc 0.950000, took 8.15 sec.
# Epoch 218: T.cost 0.048363, Train acc 0.992345, test acc 0.950000, took 8.12 sec.
# New LR: 0.000313810622902
# Epoch 219: T.cost 0.048135, Train acc 0.992345, test acc 0.950000, took 8.11 sec.
# Uniform Quantization
# Epoch 220: T.cost 0.047744, Train acc 0.992345, test acc 0.947222, took 8.23 sec.
# Epoch 221: T.cost 0.047524, Train acc 0.992345, test acc 0.950000, took 8.13 sec.
# Epoch 222: T.cost 0.047318, Train acc 0.992345, test acc 0.950000, took 8.13 sec.
# Epoch 223: T.cost 0.047116, Train acc 0.992345, test acc 0.950000, took 8.15 sec.
# Epoch 224: T.cost 0.046915, Train acc 0.992345, test acc 0.950000, took 8.13 sec.
# Epoch 225: T.cost 0.046717, Train acc 0.992345, test acc 0.950000, took 8.13 sec.
# Epoch 226: T.cost 0.046519, Train acc 0.992345, test acc 0.950000, took 8.11 sec.
# Epoch 227: T.cost 0.046321, Train acc 0.992345, test acc 0.950000, took 8.16 sec.
# Epoch 228: T.cost 0.046123, Train acc 0.992345, test acc 0.950000, took 8.14 sec.
# Epoch 229: T.cost 0.045930, Train acc 0.992345, test acc 0.950000, took 8.13 sec.
# Uniform Quantization
# Epoch 230: T.cost 0.045733, Train acc 0.992345, test acc 0.950000, took 8.23 sec.
# Epoch 231: T.cost 0.045540, Train acc 0.992345, test acc 0.950000, took 8.21 sec.
# Epoch 232: T.cost 0.045348, Train acc 0.992345, test acc 0.950000, took 8.16 sec.
# Epoch 233: T.cost 0.045154, Train acc 0.992345, test acc 0.950000, took 8.16 sec.
# Epoch 234: T.cost 0.044962, Train acc 0.992345, test acc 0.950000, took 8.14 sec.
# Epoch 235: T.cost 0.044772, Train acc 0.992345, test acc 0.950000, took 8.12 sec.
# Epoch 236: T.cost 0.044581, Train acc 0.992345, test acc 0.950000, took 8.09 sec.
# Epoch 237: T.cost 0.044393, Train acc 0.992345, test acc 0.950000, took 8.11 sec.
# Epoch 238: T.cost 0.044202, Train acc 0.992345, test acc 0.950000, took 8.07 sec.
# New LR: 0.000282429563231
# Epoch 239: T.cost 0.044016, Train acc 0.992345, test acc 0.950000, took 8.07 sec.
# Uniform Quantization
# Epoch 240: T.cost 0.043694, Train acc 0.993041, test acc 0.950000, took 8.09 sec.
# Epoch 241: T.cost 0.043512, Train acc 0.993041, test acc 0.950000, took 8.14 sec.
# Epoch 242: T.cost 0.043340, Train acc 0.993041, test acc 0.950000, took 8.1 sec.
# Epoch 243: T.cost 0.043174, Train acc 0.993737, test acc 0.950000, took 8.12 sec.
# Epoch 244: T.cost 0.043006, Train acc 0.993737, test acc 0.950000, took 8.12 sec.
# Epoch 245: T.cost 0.042838, Train acc 0.993737, test acc 0.950000, took 8.11 sec.
# Epoch 246: T.cost 0.042674, Train acc 0.993737, test acc 0.950000, took 8.15 sec.
# Epoch 247: T.cost 0.042509, Train acc 0.993737, test acc 0.950000, took 8.11 sec.
# Epoch 248: T.cost 0.042344, Train acc 0.993737, test acc 0.950000, took 8.11 sec.
# Epoch 249: T.cost 0.042179, Train acc 0.993737, test acc 0.950000, took 8.12 sec.
# Uniform Quantization
# Epoch 250: T.cost 0.042015, Train acc 0.993737, test acc 0.950000, took 8.16 sec.
# Epoch 251: T.cost 0.041852, Train acc 0.993737, test acc 0.950000, took 8.03 sec.
# Epoch 252: T.cost 0.041692, Train acc 0.993737, test acc 0.950000, took 8.0 sec.
# Epoch 253: T.cost 0.041528, Train acc 0.993737, test acc 0.950000, took 8.03 sec.
# Epoch 254: T.cost 0.041369, Train acc 0.993737, test acc 0.950000, took 8.09 sec.
# Epoch 255: T.cost 0.041207, Train acc 0.993737, test acc 0.950000, took 8.02 sec.
# Epoch 256: T.cost 0.041049, Train acc 0.993737, test acc 0.950000, took 8.09 sec.
# Epoch 257: T.cost 0.040887, Train acc 0.993737, test acc 0.950000, took 8.06 sec.
# Epoch 258: T.cost 0.040730, Train acc 0.993737, test acc 0.950000, took 8.1 sec.
# New LR: 0.000254186609527
# Epoch 259: T.cost 0.040570, Train acc 0.993737, test acc 0.950000, took 8.06 sec.
# Uniform Quantization
# Epoch 260: T.cost 0.040298, Train acc 0.993737, test acc 0.950000, took 8.14 sec.
# Epoch 261: T.cost 0.040144, Train acc 0.993737, test acc 0.950000, took 8.06 sec.
# Epoch 262: T.cost 0.039999, Train acc 0.993737, test acc 0.950000, took 8.08 sec.
# Epoch 263: T.cost 0.039858, Train acc 0.993737, test acc 0.950000, took 8.06 sec.
# Epoch 264: T.cost 0.039715, Train acc 0.993737, test acc 0.950000, took 8.06 sec.
# Epoch 265: T.cost 0.039573, Train acc 0.993737, test acc 0.950000, took 8.06 sec.
# Epoch 266: T.cost 0.039432, Train acc 0.993737, test acc 0.950000, took 8.07 sec.
# Epoch 267: T.cost 0.039293, Train acc 0.993737, test acc 0.950000, took 8.03 sec.
# Epoch 268: T.cost 0.039152, Train acc 0.993737, test acc 0.950000, took 8.06 sec.
# Epoch 269: T.cost 0.039015, Train acc 0.993737, test acc 0.950000, took 8.03 sec.
# Uniform Quantization
# Epoch 270: T.cost 0.038875, Train acc 0.993737, test acc 0.950000, took 8.2 sec.
# Epoch 271: T.cost 0.038738, Train acc 0.993737, test acc 0.950000, took 8.05 sec.
# Epoch 272: T.cost 0.038599, Train acc 0.993737, test acc 0.950000, took 8.08 sec.
# Epoch 273: T.cost 0.038461, Train acc 0.993737, test acc 0.950000, took 8.05 sec.
# Epoch 274: T.cost 0.038325, Train acc 0.993737, test acc 0.950000, took 8.11 sec.
# Epoch 275: T.cost 0.038186, Train acc 0.993737, test acc 0.950000, took 8.02 sec.
# Epoch 276: T.cost 0.038050, Train acc 0.993737, test acc 0.950000, took 8.08 sec.
# Epoch 277: T.cost 0.037914, Train acc 0.993737, test acc 0.950000, took 8.06 sec.
# Epoch 278: T.cost 0.037779, Train acc 0.993737, test acc 0.950000, took 8.09 sec.
# New LR: 0.000228767938097
# Epoch 279: T.cost 0.037645, Train acc 0.993737, test acc 0.950000, took 8.01 sec.
# Uniform Quantization
# Epoch 280: T.cost 0.037406, Train acc 0.993737, test acc 0.950000, took 8.18 sec.
# Epoch 281: T.cost 0.037277, Train acc 0.994433, test acc 0.950000, took 8.01 sec.
# Epoch 282: T.cost 0.037154, Train acc 0.994433, test acc 0.950000, took 8.05 sec.
# Epoch 283: T.cost 0.037030, Train acc 0.994433, test acc 0.950000, took 8.03 sec.
# Epoch 284: T.cost 0.036909, Train acc 0.994433, test acc 0.950000, took 8.1 sec.
# Epoch 285: T.cost 0.036787, Train acc 0.994433, test acc 0.950000, took 8.06 sec.
# Epoch 286: T.cost 0.036667, Train acc 0.994433, test acc 0.950000, took 8.08 sec.
# Epoch 287: T.cost 0.036550, Train acc 0.994433, test acc 0.950000, took 8.06 sec.
# Epoch 288: T.cost 0.036427, Train acc 0.994433, test acc 0.950000, took 8.1 sec.
# Epoch 289: T.cost 0.036309, Train acc 0.994433, test acc 0.950000, took 8.04 sec.
# Uniform Quantization
# Epoch 290: T.cost 0.036189, Train acc 0.994433, test acc 0.950000, took 8.14 sec.
# Epoch 291: T.cost 0.036070, Train acc 0.994433, test acc 0.950000, took 8.12 sec.
# Epoch 292: T.cost 0.035952, Train acc 0.994433, test acc 0.950000, took 8.12 sec.
# Epoch 293: T.cost 0.035835, Train acc 0.994433, test acc 0.950000, took 8.13 sec.
# Epoch 294: T.cost 0.035717, Train acc 0.994433, test acc 0.950000, took 8.15 sec.
# Epoch 295: T.cost 0.035599, Train acc 0.994433, test acc 0.950000, took 8.18 sec.
# Epoch 296: T.cost 0.035482, Train acc 0.994433, test acc 0.950000, took 8.14 sec.
# Epoch 297: T.cost 0.035365, Train acc 0.994433, test acc 0.952778, took 8.13 sec.
# Epoch 298: T.cost 0.035249, Train acc 0.994433, test acc 0.952778, took 8.19 sec.
# New LR: 0.000205891144287
# Epoch 299: T.cost 0.035130, Train acc 0.994433, test acc 0.952778, took 8.15 sec.
# Uniform Quantization
# Epoch 300: T.cost 0.034919, Train acc 0.994433, test acc 0.952778, took 8.21 sec.
# Epoch 301: T.cost 0.034812, Train acc 0.994433, test acc 0.952778, took 8.06 sec.
# Epoch 302: T.cost 0.034704, Train acc 0.994433, test acc 0.952778, took 8.05 sec.
# Epoch 303: T.cost 0.034599, Train acc 0.994433, test acc 0.952778, took 8.05 sec.
# Epoch 304: T.cost 0.034494, Train acc 0.994433, test acc 0.952778, took 8.13 sec.
# Epoch 305: T.cost 0.034391, Train acc 0.994433, test acc 0.952778, took 8.06 sec.
# Epoch 306: T.cost 0.034287, Train acc 0.994433, test acc 0.952778, took 8.09 sec.
# Epoch 307: T.cost 0.034183, Train acc 0.994433, test acc 0.952778, took 8.07 sec.
# Epoch 308: T.cost 0.034081, Train acc 0.994433, test acc 0.952778, took 8.07 sec.
# Epoch 309: T.cost 0.033976, Train acc 0.994433, test acc 0.952778, took 8.05 sec.
# Uniform Quantization
# Epoch 310: T.cost 0.033876, Train acc 0.994433, test acc 0.952778, took 8.15 sec.
# Epoch 311: T.cost 0.033771, Train acc 0.994433, test acc 0.952778, took 8.06 sec.
# Epoch 312: T.cost 0.033671, Train acc 0.994433, test acc 0.952778, took 8.07 sec.
# Epoch 313: T.cost 0.033570, Train acc 0.994433, test acc 0.952778, took 8.03 sec.
# Epoch 314: T.cost 0.033467, Train acc 0.994433, test acc 0.952778, took 8.06 sec.
# Epoch 315: T.cost 0.033367, Train acc 0.994433, test acc 0.952778, took 8.06 sec.
# Epoch 316: T.cost 0.033266, Train acc 0.994433, test acc 0.952778, took 8.07 sec.
# Epoch 317: T.cost 0.033165, Train acc 0.994433, test acc 0.952778, took 8.02 sec.
# Epoch 318: T.cost 0.033065, Train acc 0.995129, test acc 0.952778, took 8.08 sec.
# New LR: 0.000185302033788
# Epoch 319: T.cost 0.032964, Train acc 0.995129, test acc 0.952778, took 7.98 sec.
# Uniform Quantization
# Epoch 320: T.cost 0.032773, Train acc 0.995129, test acc 0.952778, took 8.12 sec.
# Epoch 321: T.cost 0.032683, Train acc 0.995129, test acc 0.952778, took 8.07 sec.
# Epoch 322: T.cost 0.032590, Train acc 0.995129, test acc 0.952778, took 8.13 sec.
# Epoch 323: T.cost 0.032500, Train acc 0.995129, test acc 0.952778, took 8.03 sec.
# Epoch 324: T.cost 0.032411, Train acc 0.995129, test acc 0.952778, took 8.07 sec.
# Epoch 325: T.cost 0.032320, Train acc 0.995129, test acc 0.952778, took 8.04 sec.
# Epoch 326: T.cost 0.032231, Train acc 0.995129, test acc 0.952778, took 8.05 sec.
# Epoch 327: T.cost 0.032142, Train acc 0.995129, test acc 0.952778, took 8.1 sec.
# Epoch 328: T.cost 0.032056, Train acc 0.995129, test acc 0.952778, took 8.08 sec.
# Epoch 329: T.cost 0.031965, Train acc 0.995129, test acc 0.952778, took 8.08 sec.
# Uniform Quantization
# Epoch 330: T.cost 0.031879, Train acc 0.995129, test acc 0.952778, took 8.15 sec.
# Epoch 331: T.cost 0.031789, Train acc 0.995129, test acc 0.952778, took 8.03 sec.
# Epoch 332: T.cost 0.031700, Train acc 0.995129, test acc 0.952778, took 8.08 sec.
# Epoch 333: T.cost 0.031614, Train acc 0.995129, test acc 0.952778, took 8.02 sec.
# Epoch 334: T.cost 0.031527, Train acc 0.995129, test acc 0.952778, took 8.07 sec.
# Epoch 335: T.cost 0.031440, Train acc 0.995129, test acc 0.952778, took 8.04 sec.
# Epoch 336: T.cost 0.031353, Train acc 0.995129, test acc 0.952778, took 8.08 sec.
# Epoch 337: T.cost 0.031265, Train acc 0.995129, test acc 0.952778, took 8.01 sec.
# Epoch 338: T.cost 0.031178, Train acc 0.995129, test acc 0.952778, took 8.05 sec.
# New LR: 0.000166771833028
# Epoch 339: T.cost 0.031093, Train acc 0.995129, test acc 0.952778, took 8.05 sec.
# Uniform Quantization
# Epoch 340: T.cost 0.030924, Train acc 0.995129, test acc 0.952778, took 8.15 sec.
# Epoch 341: T.cost 0.030843, Train acc 0.995129, test acc 0.952778, took 8.04 sec.
# Epoch 342: T.cost 0.030765, Train acc 0.995129, test acc 0.952778, took 8.08 sec.
# Epoch 343: T.cost 0.030687, Train acc 0.995129, test acc 0.952778, took 8.06 sec.
# Epoch 344: T.cost 0.030612, Train acc 0.995129, test acc 0.952778, took 8.06 sec.
# Epoch 345: T.cost 0.030533, Train acc 0.995129, test acc 0.952778, took 8.02 sec.
# Epoch 346: T.cost 0.030457, Train acc 0.995129, test acc 0.952778, took 8.1 sec.
# Epoch 347: T.cost 0.030381, Train acc 0.995129, test acc 0.952778, took 8.02 sec.
# Epoch 348: T.cost 0.030305, Train acc 0.995129, test acc 0.952778, took 8.07 sec.
# Epoch 349: T.cost 0.030229, Train acc 0.995129, test acc 0.950000, took 8.02 sec.
# Uniform Quantization
# Epoch 350: T.cost 0.030152, Train acc 0.995825, test acc 0.950000, took 8.19 sec.
# Epoch 351: T.cost 0.030076, Train acc 0.995825, test acc 0.950000, took 8.06 sec.
# Epoch 352: T.cost 0.030002, Train acc 0.995825, test acc 0.950000, took 8.15 sec.
# Epoch 353: T.cost 0.029926, Train acc 0.995825, test acc 0.950000, took 8.16 sec.
# Epoch 354: T.cost 0.029850, Train acc 0.995825, test acc 0.950000, took 8.1 sec.
# Epoch 355: T.cost 0.029774, Train acc 0.995825, test acc 0.950000, took 8.08 sec.
# Epoch 356: T.cost 0.029699, Train acc 0.995825, test acc 0.950000, took 8.16 sec.
# Epoch 357: T.cost 0.029624, Train acc 0.995825, test acc 0.950000, took 8.1 sec.
# Epoch 358: T.cost 0.029550, Train acc 0.995825, test acc 0.950000, took 8.18 sec.
# New LR: 0.000150094648416
# Epoch 359: T.cost 0.029476, Train acc 0.995825, test acc 0.950000, took 8.16 sec.
# Uniform Quantization
# Epoch 360: T.cost 0.029326, Train acc 0.995825, test acc 0.950000, took 8.25 sec.
# Epoch 361: T.cost 0.029256, Train acc 0.995825, test acc 0.950000, took 8.03 sec.
# Epoch 362: T.cost 0.029190, Train acc 0.995825, test acc 0.950000, took 8.08 sec.
# Epoch 363: T.cost 0.029123, Train acc 0.995825, test acc 0.950000, took 8.05 sec.
# Epoch 364: T.cost 0.029057, Train acc 0.995825, test acc 0.950000, took 8.06 sec.
# Epoch 365: T.cost 0.028990, Train acc 0.995825, test acc 0.950000, took 8.09 sec.
# Epoch 366: T.cost 0.028926, Train acc 0.995825, test acc 0.950000, took 8.1 sec.
# Epoch 367: T.cost 0.028858, Train acc 0.995825, test acc 0.950000, took 8.05 sec.
# Epoch 368: T.cost 0.028793, Train acc 0.995825, test acc 0.950000, took 8.06 sec.
# Epoch 369: T.cost 0.028727, Train acc 0.995825, test acc 0.950000, took 8.06 sec.
# Uniform Quantization
# Epoch 370: T.cost 0.028660, Train acc 0.995825, test acc 0.950000, took 8.13 sec.
# Epoch 371: T.cost 0.028597, Train acc 0.995825, test acc 0.950000, took 8.07 sec.
# Epoch 372: T.cost 0.028530, Train acc 0.995825, test acc 0.950000, took 8.22 sec.
# Epoch 373: T.cost 0.028465, Train acc 0.995825, test acc 0.950000, took 8.03 sec.
# Epoch 374: T.cost 0.028400, Train acc 0.995825, test acc 0.950000, took 8.14 sec.
# Epoch 375: T.cost 0.028334, Train acc 0.995825, test acc 0.950000, took 8.04 sec.
# Epoch 376: T.cost 0.028270, Train acc 0.995825, test acc 0.950000, took 8.1 sec.
# Epoch 377: T.cost 0.028205, Train acc 0.995825, test acc 0.950000, took 8.11 sec.
# Epoch 378: T.cost 0.028139, Train acc 0.995825, test acc 0.950000, took 8.11 sec.
# New LR: 0.000135085187503
# Epoch 379: T.cost 0.028076, Train acc 0.995825, test acc 0.950000, took 8.09 sec.
# Uniform Quantization
# Epoch 380: T.cost 0.027945, Train acc 0.995825, test acc 0.950000, took 8.24 sec.
# Epoch 381: T.cost 0.027885, Train acc 0.995825, test acc 0.950000, took 8.08 sec.
# Epoch 382: T.cost 0.027827, Train acc 0.995825, test acc 0.950000, took 8.12 sec.
# Epoch 383: T.cost 0.027770, Train acc 0.995825, test acc 0.950000, took 8.04 sec.
# Epoch 384: T.cost 0.027713, Train acc 0.995825, test acc 0.950000, took 8.2 sec.
# Epoch 385: T.cost 0.027656, Train acc 0.995825, test acc 0.950000, took 8.1 sec.
# Epoch 386: T.cost 0.027597, Train acc 0.995825, test acc 0.950000, took 8.18 sec.
# Epoch 387: T.cost 0.027539, Train acc 0.995825, test acc 0.950000, took 8.16 sec.
# Epoch 388: T.cost 0.027483, Train acc 0.995825, test acc 0.950000, took 8.23 sec.
# Epoch 389: T.cost 0.027427, Train acc 0.995825, test acc 0.950000, took 8.12 sec.
# Uniform Quantization
# Epoch 390: T.cost 0.027368, Train acc 0.995825, test acc 0.950000, took 8.22 sec.
# Epoch 391: T.cost 0.027313, Train acc 0.995825, test acc 0.950000, took 8.27 sec.
# Epoch 392: T.cost 0.027257, Train acc 0.995825, test acc 0.950000, took 8.45 sec.
# Epoch 393: T.cost 0.027200, Train acc 0.995825, test acc 0.950000, took 8.17 sec.
# Epoch 394: T.cost 0.027143, Train acc 0.995825, test acc 0.950000, took 8.21 sec.
# Epoch 395: T.cost 0.027086, Train acc 0.995825, test acc 0.950000, took 8.14 sec.
# Epoch 396: T.cost 0.027031, Train acc 0.995825, test acc 0.950000, took 8.35 sec.
# Epoch 397: T.cost 0.026973, Train acc 0.995825, test acc 0.950000, took 8.12 sec.
# Epoch 398: T.cost 0.026918, Train acc 0.995825, test acc 0.950000, took 8.19 sec.
# New LR: 0.000121576663514
# Epoch 399: T.cost 0.026861, Train acc 0.995825, test acc 0.950000, took 8.09 sec.
# Uniform Quantization
# Epoch 400: T.cost 0.026746, Train acc 0.995825, test acc 0.950000, took 8.29 sec.
# Epoch 401: T.cost 0.026696, Train acc 0.996521, test acc 0.950000, took 8.23 sec.
# Epoch 402: T.cost 0.026645, Train acc 0.996521, test acc 0.950000, took 8.34 sec.
# Epoch 403: T.cost 0.026594, Train acc 0.996521, test acc 0.950000, took 8.36 sec.
# Epoch 404: T.cost 0.026544, Train acc 0.996521, test acc 0.950000, took 8.38 sec.
# Epoch 405: T.cost 0.026495, Train acc 0.996521, test acc 0.950000, took 8.25 sec.
# Epoch 406: T.cost 0.026446, Train acc 0.996521, test acc 0.950000, took 8.44 sec.
# Epoch 407: T.cost 0.026396, Train acc 0.996521, test acc 0.950000, took 8.31 sec.
# Epoch 408: T.cost 0.026346, Train acc 0.996521, test acc 0.950000, took 8.84 sec.
# Epoch 409: T.cost 0.026296, Train acc 0.996521, test acc 0.950000, took 8.53 sec.
# Uniform Quantization
# Epoch 410: T.cost 0.026246, Train acc 0.996521, test acc 0.950000, took 8.65 sec.
# Epoch 411: T.cost 0.026197, Train acc 0.996521, test acc 0.950000, took 8.48 sec.
# Epoch 412: T.cost 0.026147, Train acc 0.996521, test acc 0.950000, took 8.48 sec.
# Epoch 413: T.cost 0.026098, Train acc 0.996521, test acc 0.950000, took 8.36 sec.
# Epoch 414: T.cost 0.026048, Train acc 0.996521, test acc 0.950000, took 8.41 sec.
# Epoch 415: T.cost 0.026000, Train acc 0.996521, test acc 0.950000, took 8.35 sec.
# Epoch 416: T.cost 0.025950, Train acc 0.996521, test acc 0.950000, took 8.45 sec.
# Epoch 417: T.cost 0.025902, Train acc 0.996521, test acc 0.950000, took 8.56 sec.
# Epoch 418: T.cost 0.025852, Train acc 0.996521, test acc 0.950000, took 8.68 sec.
# New LR: 0.000109418994543
# Epoch 419: T.cost 0.025804, Train acc 0.996521, test acc 0.950000, took 8.59 sec.
# Uniform Quantization
# Epoch 420: T.cost 0.025702, Train acc 0.996521, test acc 0.950000, took 8.68 sec.
# Epoch 421: T.cost 0.025656, Train acc 0.996521, test acc 0.950000, took 8.3 sec.
# Epoch 422: T.cost 0.025614, Train acc 0.996521, test acc 0.950000, took 8.32 sec.
# Epoch 423: T.cost 0.025569, Train acc 0.996521, test acc 0.950000, took 8.46 sec.
# Epoch 424: T.cost 0.025527, Train acc 0.996521, test acc 0.950000, took 8.54 sec.
# Epoch 425: T.cost 0.025483, Train acc 0.996521, test acc 0.950000, took 8.4 sec.
# Epoch 426: T.cost 0.025439, Train acc 0.996521, test acc 0.950000, took 8.5 sec.
# Epoch 427: T.cost 0.025395, Train acc 0.996521, test acc 0.950000, took 8.29 sec.
# Epoch 428: T.cost 0.025351, Train acc 0.996521, test acc 0.950000, took 8.39 sec.
# Epoch 429: T.cost 0.025308, Train acc 0.996521, test acc 0.950000, took 8.3 sec.
# Uniform Quantization
# Epoch 430: T.cost 0.025265, Train acc 0.996521, test acc 0.950000, took 8.46 sec.
# Epoch 431: T.cost 0.025222, Train acc 0.996521, test acc 0.950000, took 8.4 sec.
# Epoch 432: T.cost 0.025178, Train acc 0.996521, test acc 0.950000, took 8.36 sec.
# Epoch 433: T.cost 0.025135, Train acc 0.996521, test acc 0.950000, took 8.33 sec.
# Epoch 434: T.cost 0.025092, Train acc 0.996521, test acc 0.950000, took 8.43 sec.
# Epoch 435: T.cost 0.025048, Train acc 0.996521, test acc 0.950000, took 8.32 sec.
# Epoch 436: T.cost 0.025004, Train acc 0.996521, test acc 0.950000, took 8.53 sec.
# Epoch 437: T.cost 0.024961, Train acc 0.996521, test acc 0.950000, took 8.35 sec.
# Epoch 438: T.cost 0.024920, Train acc 0.996521, test acc 0.950000, took 8.48 sec.
# New LR: 9.84770944342e-05
# Epoch 439: T.cost 0.024876, Train acc 0.996521, test acc 0.950000, took 8.37 sec.
# Uniform Quantization
# Epoch 440: T.cost 0.024786, Train acc 0.996521, test acc 0.950000, took 8.57 sec.
# Epoch 441: T.cost 0.024748, Train acc 0.996521, test acc 0.950000, took 8.39 sec.
# Epoch 442: T.cost 0.024710, Train acc 0.996521, test acc 0.950000, took 8.44 sec.
# Epoch 443: T.cost 0.024672, Train acc 0.996521, test acc 0.950000, took 8.3 sec.
# Epoch 444: T.cost 0.024632, Train acc 0.996521, test acc 0.950000, took 8.41 sec.
# Epoch 445: T.cost 0.024595, Train acc 0.996521, test acc 0.950000, took 8.31 sec.
# Epoch 446: T.cost 0.024555, Train acc 0.996521, test acc 0.950000, took 8.34 sec.
# Epoch 447: T.cost 0.024516, Train acc 0.996521, test acc 0.950000, took 8.37 sec.
# Epoch 448: T.cost 0.024480, Train acc 0.996521, test acc 0.950000, took 8.34 sec.
# Epoch 449: T.cost 0.024440, Train acc 0.996521, test acc 0.950000, took 8.35 sec.
# Uniform Quantization
# Epoch 450: T.cost 0.024403, Train acc 0.996521, test acc 0.950000, took 8.56 sec.
# Epoch 451: T.cost 0.024366, Train acc 0.996521, test acc 0.950000, took 8.39 sec.
# Epoch 452: T.cost 0.024328, Train acc 0.996521, test acc 0.950000, took 8.49 sec.
# Epoch 453: T.cost 0.024289, Train acc 0.996521, test acc 0.950000, took 8.42 sec.
# Epoch 454: T.cost 0.024249, Train acc 0.996521, test acc 0.950000, took 8.41 sec.
# Epoch 455: T.cost 0.024211, Train acc 0.996521, test acc 0.950000, took 8.42 sec.
# Epoch 456: T.cost 0.024174, Train acc 0.996521, test acc 0.950000, took 8.45 sec.
# Epoch 457: T.cost 0.024136, Train acc 0.996521, test acc 0.950000, took 8.41 sec.
# Epoch 458: T.cost 0.024097, Train acc 0.996521, test acc 0.950000, took 8.5 sec.
# New LR: 8.86293863005e-05
# Epoch 459: T.cost 0.024061, Train acc 0.996521, test acc 0.950000, took 8.51 sec.
# Uniform Quantization
# Epoch 460: T.cost 0.023981, Train acc 0.996521, test acc 0.950000, took 8.63 sec.
# Epoch 461: T.cost 0.023946, Train acc 0.996521, test acc 0.950000, took 8.65 sec.
# Epoch 462: T.cost 0.023914, Train acc 0.996521, test acc 0.950000, took 8.63 sec.
# Epoch 463: T.cost 0.023879, Train acc 0.996521, test acc 0.950000, took 8.66 sec.
# Epoch 464: T.cost 0.023845, Train acc 0.996521, test acc 0.950000, took 8.6 sec.
# Epoch 465: T.cost 0.023811, Train acc 0.996521, test acc 0.950000, took 8.5 sec.
# Epoch 466: T.cost 0.023776, Train acc 0.996521, test acc 0.950000, took 8.41 sec.
# Epoch 467: T.cost 0.023742, Train acc 0.996521, test acc 0.950000, took 8.42 sec.
# Epoch 468: T.cost 0.023709, Train acc 0.996521, test acc 0.950000, took 8.38 sec.
# Epoch 469: T.cost 0.023674, Train acc 0.996521, test acc 0.950000, took 8.42 sec.
# Uniform Quantization
# Epoch 470: T.cost 0.023641, Train acc 0.996521, test acc 0.950000, took 8.48 sec.
# Epoch 471: T.cost 0.023607, Train acc 0.996521, test acc 0.950000, took 8.35 sec.
# Epoch 472: T.cost 0.023574, Train acc 0.996521, test acc 0.950000, took 8.35 sec.
# Epoch 473: T.cost 0.023539, Train acc 0.996521, test acc 0.950000, took 8.36 sec.
# Epoch 474: T.cost 0.023507, Train acc 0.996521, test acc 0.950000, took 8.33 sec.
# Epoch 475: T.cost 0.023471, Train acc 0.996521, test acc 0.950000, took 8.34 sec.
# Epoch 476: T.cost 0.023438, Train acc 0.996521, test acc 0.950000, took 8.36 sec.
# Epoch 477: T.cost 0.023404, Train acc 0.996521, test acc 0.950000, took 8.35 sec.
# Epoch 478: T.cost 0.023371, Train acc 0.996521, test acc 0.950000, took 8.34 sec.
# New LR: 7.97664470156e-05
# Epoch 479: T.cost 0.023337, Train acc 0.996521, test acc 0.950000, took 8.34 sec.
# Uniform Quantization
# Epoch 480: T.cost 0.023266, Train acc 0.996521, test acc 0.950000, took 8.45 sec.
# Epoch 481: T.cost 0.023235, Train acc 0.996521, test acc 0.950000, took 8.36 sec.
# Epoch 482: T.cost 0.023207, Train acc 0.996521, test acc 0.950000, took 8.33 sec.
# Epoch 483: T.cost 0.023177, Train acc 0.996521, test acc 0.950000, took 8.36 sec.
# Epoch 484: T.cost 0.023146, Train acc 0.996521, test acc 0.950000, took 8.35 sec.
# Epoch 485: T.cost 0.023114, Train acc 0.996521, test acc 0.950000, took 8.34 sec.
# Epoch 486: T.cost 0.023086, Train acc 0.996521, test acc 0.950000, took 8.33 sec.
# Epoch 487: T.cost 0.023056, Train acc 0.996521, test acc 0.950000, took 8.35 sec.
# Epoch 488: T.cost 0.023025, Train acc 0.996521, test acc 0.950000, took 8.33 sec.
# Epoch 489: T.cost 0.022994, Train acc 0.996521, test acc 0.950000, took 8.46 sec.
# Uniform Quantization
# Epoch 490: T.cost 0.022964, Train acc 0.996521, test acc 0.950000, took 8.57 sec.
# Epoch 491: T.cost 0.022933, Train acc 0.996521, test acc 0.950000, took 8.44 sec.
# Epoch 492: T.cost 0.022905, Train acc 0.996521, test acc 0.950000, took 8.39 sec.
# Epoch 493: T.cost 0.022874, Train acc 0.996521, test acc 0.950000, took 8.43 sec.
# Epoch 494: T.cost 0.022843, Train acc 0.996521, test acc 0.950000, took 8.41 sec.
# Epoch 495: T.cost 0.022813, Train acc 0.996521, test acc 0.950000, took 8.39 sec.
# Epoch 496: T.cost 0.022783, Train acc 0.996521, test acc 0.950000, took 8.42 sec.
# Epoch 497: T.cost 0.022753, Train acc 0.996521, test acc 0.950000, took 8.36 sec.
# Epoch 498: T.cost 0.022723, Train acc 0.996521, test acc 0.950000, took 8.36 sec.
# New LR: 7.1789802314e-05
# Epoch 499: T.cost 0.022692, Train acc 0.996521, test acc 0.950000, took 8.31 sec.
#
# Total time spent: 4061.0 seconds
# Traing Acc: 0.99652052888
# Test Acc: 0.95

# %% [markdown]
# # HISTOGRAM

# %%
disc_output_r = disc_output.reshape((-1, QUANT_UNIT))
dense_output_r = param_output.reshape((-1, QUANT_UNIT))

plt.figure()
plt.plot(dense_output_r[:, 4], disc_output_r[:, 4], '.')

# %%
plt.figure(figsize=(8,8))
plt.semilogy(1-np.array(train_accs), label='Training Error')
plt.semilogy(1-np.array(test_accs), label='Test Error')
plt.legend(fontsize=20)
plt.xlabel('Epoch', fontsize=8)
plt.ylabel('Error', fontsize=8)
plt.grid(True)
plt.show()
