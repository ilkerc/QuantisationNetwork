# %%
# %matplotlib inline
import os
import time
# os.environ['THEANO_FLAGS']='contexts=dev0->cuda0;dev1->cuda1'
os.environ['THEANO_FLAGS']='device=gpu1'
import theano
import lasagne
import numpy as np
import cPickle as pickle
import theano.tensor as T
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits as load_sk_dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
from lasagne.layers import InputLayer, DenseLayer, DropoutLayer
from helpers.DiscreteLayer import DiscreteLayer
# Out:
# Using gpu device 1: Tesla K40c (CNMeM is enabled with initial size: 40.0% of memory, cuDNN 5005)

# %% [markdown]
# # Breast Cancer dataset cl
# * 30 Dimensions of Features
# * 2 Classes
# * 569 examples (212(M),357(B))
#
# I'll be using ML.Perceptron, for classification

# %%
# Constants
NUM_EPOCHS = 500
BATCH_SIZE = 10
LEARNING_RATE = 0.001

# Disc. Layer Settings
DISC = True
QUANT_UNIT = 5
QUANT = np.array(np.repeat(0.125, QUANT_UNIT), dtype='float32')
VARIANCE_DEVIDER = 2.0
ADDITIONAL_COST = True
# Uniform Settings
UNIFORM_QUANT = False
UNIFORM_STEP = 10000

# Test Specs
TEST_NAME = 'digits-qnonuniform-var6'

# Additional Settings
lasagne.random.set_rng(np.random.RandomState(12345))  # Set random state so we can investigate results
np.random.seed(1234)
#theano.config.exception_verbosity = 'high'

# %%
def load_dataset():
    dataset = load_sk_dataset()
    X = dataset['data']
    no_classes = len(np.unique(dataset['target']))
    X = normalize(X, norm='l2')
    #     X = (X - X.mean()) / X.std()
    Y = dataset['target']
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=41)
    return dict(X_train=X_train,
               y_train=y_train,
               X_test=X_test,
               y_test=y_test,
               classes=no_classes)
data = load_dataset()
NUM_CLASSES = data['classes']

# %%
def build_mlp(Xs, disc, classnum, QUANT_UNIT):
    tanh = lasagne.nonlinearities.tanh
    softmax = lasagne.nonlinearities.softmax
    
    l_in = InputLayer(shape=Xs.shape)
    l_dense1 = DenseLayer(l_in, num_units=25, nonlinearity=tanh)
    l_dense2 = DenseLayer(l_dense1, num_units=QUANT_UNIT, nonlinearity=tanh, name='param_regressor')
    if disc:
        sharedBins = theano.shared(None, name='sharedBins')
        l_dis = DiscreteLayer(l_dense2, sharedBins=sharedBins, name='disclayer')
        print("Using Discret. Layer")
    else:
        l_dis = l_dense2
        print("No Disc. Layer")
    l_class = DenseLayer(l_dis, num_units=classnum, nonlinearity=softmax)
    
    if disc:
        return l_class, sharedBins
    else:
        return l_class

if DISC:
    model, sharedBins = build_mlp(data['X_train'], disc=DISC, classnum=NUM_CLASSES, QUANT_UNIT=QUANT_UNIT)
else:
    model = build_mlp(data['X_train'], disc=DISC, classnum=NUM_CLASSES, QUANT_UNIT=QUANT_UNIT)
model_params = lasagne.layers.get_all_params(model, trainable=True)
# Out:
# Using Discret. Layer

# %%
"""
Input: dist, dist.shape = (-1, num_units)
Find quantization bins of a given dist history
Returns a list of (x, num_units), where x's length is a random variable
"""
def find_quantization_bins(dist, sharedBins):
    # Quantizer function
    def Q(x, y):
        return y * np.floor((x/y) + .5)
    
    shape = dist.shape
    init_Q = QUANT
    final_Q = []
    
    # If Uniform Quantization
    if UNIFORM_QUANT:
        uniform_bin = np.linspace(-1, 1, UNIFORM_STEP)
        uniform_bins = np.tile(uniform_bin, (shape[0], 1))
        sharedBins.set_value(uniform_bins)
        print "Uniform Quantization"
        return uniform_bins
    
    # Theta iterator
    for i in range(shape[1]):
        theta_i = dist[:, i]
        
        # Whats is the error threshold for this distribution
        Q_eps = np.var(theta_i) / VARIANCE_DEVIDER
        
        # Batch Iterator
        final_Q_i = []
        for j in range(shape[0]):
            theta = theta_i[j]
            
            # Quantized theta = Quantization bins
            q = init_Q[i]
            x_i = theta
            x_o = Q(x_i, q)
            
            # Optimize x_o

            while(np.abs(x_o - x_i) > Q_eps):
                q = q / 2
                x_o = Q(x_i, q)
            
            # End of optimisation
            final_Q_i.append(x_o)
        
        # Append to outer list
        uniques = np.unique(np.array(final_Q_i))
        final_Q.append(uniques.astype(theano.config.floatX))
        
    # Report
    print "New Bin Sizes: [" + ", ".join([str(final_Q[x].shape[0]) for x in range(shape[1])] ) + "]"
    sharedBins.set_value(final_Q)
    return final_Q

# %%
def build_functions():
    X = T.matrix(dtype=theano.config.floatX)
    y = T.ivector()

    ## Layer History
    if DISC:
        l_disc = next(l for l in lasagne.layers.get_all_layers(model) if l.name is 'disclayer')
        l_paramreg = next(l for l in lasagne.layers.get_all_layers(model) if l.name is 'param_regressor')
        l_disc_output, l_paramreg_output = lasagne.layers.get_output([l_disc, l_paramreg], X, deterministic=False)
    ## Layer History

    # training output
    output_train = lasagne.layers.get_output(model, X, deterministic=False)

    # evaluation output. Also includes output of transform for plotting
    output_eval = lasagne.layers.get_output(model, X, deterministic=True)

    sh_lr = theano.shared(lasagne.utils.floatX(LEARNING_RATE))
    cost = T.mean(T.nnet.categorical_crossentropy(output_train, y))
    
    if ADDITIONAL_COST and DISC:
        cost += T.mean(lasagne.objectives.squared_error(l_disc_output, l_paramreg_output))
    
    updates = lasagne.updates.adam(cost, model_params, learning_rate=sh_lr)
    
    # updates = lasagne.updates.nesterov_momentum(cost, model_params, learning_rate=0.01, momentum=0.9)

    if DISC:
        train = theano.function([X, y], [cost, output_train, l_disc_output, l_paramreg_output], updates=updates, allow_input_downcast=True)
    else:
        train = theano.function([X, y], [cost, output_train], updates=updates, allow_input_downcast=True)
    eval = theano.function([X], [output_eval], allow_input_downcast=True)
    
    return train, eval, sh_lr

train, eval, sh_lr = build_functions()

# %%
def train_epoch(X, y):
    # History Keeping
    param_output = []
    disc_output = []
    # History
    num_samples = X.shape[0]
    num_batches = int(np.ceil(num_samples / float(BATCH_SIZE)))
    costs = []
    correct = 0
    for i in range(num_batches):
        idx = range(i*BATCH_SIZE, np.minimum((i+1)*BATCH_SIZE, num_samples))
        X_batch = X[idx]
        y_batch = y[idx]
        if DISC:
            cost, output_train, l_disc_output, l_paramreg_output = train(X_batch, y_batch)
            param_output = np.append(param_output, l_paramreg_output)
            disc_output = np.append(disc_output, l_disc_output)
        else:
            cost, output_train = train(X_batch, y_batch)
        costs += [cost]
        preds = np.argmax(output_train, axis=-1)
        correct += np.sum(y_batch == preds)
    
    return np.mean(costs), correct / float(num_samples), param_output, disc_output


def eval_epoch(X, y):
    output_eval = eval(X)
    preds = np.argmax(output_eval, axis=-1)
    acc = np.mean(preds == y)
    return acc

# %%
np.set_printoptions(formatter={'float': '{: 0.4f}'.format}, suppress=True)
train_accs, test_accs = [], []
total_time = 0
param_outputs, disc_outputs = [], []
disc_dist_t_1 = None
quantized_bins = []
try:
    for n in range(NUM_EPOCHS):
        start_time = time.time()
        train_cost, train_acc, param_output, disc_output = train_epoch(data['X_train'], data['y_train'])
        test_acc = eval_epoch(data['X_test'], data['y_test'])
        test_accs += [test_acc]
        train_accs += [train_acc]

        if DISC:
            param_outputs = np.append(param_outputs, param_output)
            disc_outputs = np.append(disc_outputs, disc_output)

        if (n+1) % 20 == 0:
            new_lr = sh_lr.get_value() * 0.90
            print "New LR:", new_lr
            sh_lr.set_value(lasagne.utils.floatX(new_lr))
        
        # Non-uniform Quantization
        if DISC:
            if n>0 and np.mod(n, 10) == 0:
                dist = disc_output.reshape((-1, QUANT_UNIT))
                q_bins = find_quantization_bins(dist, sharedBins=sharedBins)
                quantized_bins.append(q_bins)

        time_spent = time.time() - start_time
        total_time += time_spent
        print "Epoch {0}: T.cost {1:0.6f}, Train acc {2:0.6f}, test acc {3:0.6f}, took {4:.3} sec.".format(
                n, train_cost, train_acc, test_acc, time_spent)

except KeyboardInterrupt:
    pass
print "\nTotal time spent: {0:.5} seconds\nTraing Acc: {1}\nTest Acc: {2}\n".format(total_time, train_acc, test_acc) 

if DISC:
    story = {'train_accs': train_accs,
             'test_accs': test_accs,
             'epoch_reached': n, 
             'total_time': total_time,
             'disc_enabled': DISC,
             'learning_rate': LEARNING_RATE,
             'batch_size': BATCH_SIZE,
             'dense_params': param_output,
             'disc_params': disc_output,
             'quantized_bins': quantized_bins}
else:
    story = {'train_accs': train_accs,
             'test_accs': test_accs,
             'epoch_reached': n, 
             'total_time': total_time,
             'disc_enabled': DISC,
             'learning_rate': LEARNING_RATE,
             'batch_size': BATCH_SIZE,
             'disc_params': disc_output}   

with open(TEST_NAME + '.model', 'wb') as fp:
  pickle.dump(story, fp)
# Out:
# Epoch 0: T.cost 2.193990, Train acc 0.265136, test acc 0.402778, took 0.121 sec.
# Epoch 1: T.cost 1.905052, Train acc 0.463466, test acc 0.472222, took 0.119 sec.
# Epoch 2: T.cost 1.581611, Train acc 0.543493, test acc 0.575000, took 0.121 sec.
# Epoch 3: T.cost 1.344940, Train acc 0.620042, test acc 0.644444, took 0.119 sec.
# Epoch 4: T.cost 1.187123, Train acc 0.654141, test acc 0.663889, took 0.115 sec.
# Epoch 5: T.cost 1.073210, Train acc 0.672930, test acc 0.672222, took 0.098 sec.
# Epoch 6: T.cost 0.983326, Train acc 0.703549, test acc 0.700000, took 0.0972 sec.
# Epoch 7: T.cost 0.908940, Train acc 0.736952, test acc 0.722222, took 0.0986 sec.
# Epoch 8: T.cost 0.845830, Train acc 0.768267, test acc 0.744444, took 0.0991 sec.
# Epoch 9: T.cost 0.791274, Train acc 0.789840, test acc 0.769444, took 0.0968 sec.
# New Bin Sizes: [17, 17, 17, 17, 17]
# Epoch 10: T.cost 0.743539, Train acc 0.798887, test acc 0.780556, took 0.129 sec.
# Epoch 11: T.cost 0.698414, Train acc 0.816980, test acc 0.783333, took 0.222 sec.
# Epoch 12: T.cost 0.661864, Train acc 0.827418, test acc 0.791667, took 0.248 sec.
# Epoch 13: T.cost 0.628338, Train acc 0.837857, test acc 0.805556, took 0.234 sec.
# Epoch 14: T.cost 0.599712, Train acc 0.842032, test acc 0.822222, took 0.225 sec.
# Epoch 15: T.cost 0.574324, Train acc 0.848991, test acc 0.830556, took 0.184 sec.
# Epoch 16: T.cost 0.549047, Train acc 0.853862, test acc 0.847222, took 0.243 sec.
# Epoch 17: T.cost 0.526443, Train acc 0.859429, test acc 0.850000, took 0.23 sec.
# Epoch 18: T.cost 0.506243, Train acc 0.868476, test acc 0.869444, took 0.182 sec.
# New LR: 0.000900000042748
# Epoch 19: T.cost 0.487372, Train acc 0.869868, test acc 0.863889, took 0.185 sec.
# New Bin Sizes: [17, 17, 17, 17, 17]
# Epoch 20: T.cost 0.466627, Train acc 0.876827, test acc 0.877778, took 0.214 sec.
# Epoch 21: T.cost 0.448711, Train acc 0.883786, test acc 0.880556, took 0.184 sec.
# Epoch 22: T.cost 0.432117, Train acc 0.888657, test acc 0.888889, took 0.185 sec.
# Epoch 23: T.cost 0.415100, Train acc 0.892832, test acc 0.894444, took 0.183 sec.
# Epoch 24: T.cost 0.398264, Train acc 0.903271, test acc 0.900000, took 0.184 sec.
# Epoch 25: T.cost 0.383791, Train acc 0.904662, test acc 0.900000, took 0.183 sec.
# Epoch 26: T.cost 0.369137, Train acc 0.914405, test acc 0.900000, took 0.184 sec.
# Epoch 27: T.cost 0.354512, Train acc 0.919972, test acc 0.902778, took 0.183 sec.
# Epoch 28: T.cost 0.339585, Train acc 0.924148, test acc 0.911111, took 0.184 sec.
# Epoch 29: T.cost 0.326558, Train acc 0.930411, test acc 0.913889, took 0.183 sec.
# New Bin Sizes: [17, 17, 17, 17, 17]
# Epoch 30: T.cost 0.314417, Train acc 0.930411, test acc 0.919444, took 0.212 sec.
# Epoch 31: T.cost 0.303031, Train acc 0.934586, test acc 0.922222, took 0.183 sec.
# Epoch 32: T.cost 0.291149, Train acc 0.936674, test acc 0.925000, took 0.187 sec.
# Epoch 33: T.cost 0.280549, Train acc 0.943633, test acc 0.930556, took 0.184 sec.
# Epoch 34: T.cost 0.270734, Train acc 0.944328, test acc 0.925000, took 0.184 sec.
# Epoch 35: T.cost 0.263112, Train acc 0.945720, test acc 0.927778, took 0.184 sec.
# Epoch 36: T.cost 0.254357, Train acc 0.946416, test acc 0.930556, took 0.185 sec.
# Epoch 37: T.cost 0.246062, Train acc 0.947808, test acc 0.936111, took 0.276 sec.
# Epoch 38: T.cost 0.240375, Train acc 0.948504, test acc 0.936111, took 0.25 sec.
# New LR: 0.000810000038473
# Epoch 39: T.cost 0.232151, Train acc 0.950592, test acc 0.936111, took 0.247 sec.
# New Bin Sizes: [17, 17, 17, 17, 17]
# Epoch 40: T.cost 0.223323, Train acc 0.953375, test acc 0.936111, took 0.248 sec.
# Epoch 41: T.cost 0.217873, Train acc 0.954071, test acc 0.936111, took 0.193 sec.
# Epoch 42: T.cost 0.212723, Train acc 0.958246, test acc 0.936111, took 0.193 sec.
# Epoch 43: T.cost 0.207762, Train acc 0.958246, test acc 0.936111, took 0.192 sec.
# Epoch 44: T.cost 0.202748, Train acc 0.958246, test acc 0.936111, took 0.193 sec.
# Epoch 45: T.cost 0.198570, Train acc 0.957550, test acc 0.936111, took 0.193 sec.
# Epoch 46: T.cost 0.194520, Train acc 0.957550, test acc 0.936111, took 0.244 sec.
# Epoch 47: T.cost 0.189872, Train acc 0.959638, test acc 0.938889, took 0.246 sec.
# Epoch 48: T.cost 0.185704, Train acc 0.961726, test acc 0.938889, took 0.255 sec.
# Epoch 49: T.cost 0.181754, Train acc 0.961726, test acc 0.936111, took 0.244 sec.
# New Bin Sizes: [17, 17, 16, 17, 17]
# Epoch 50: T.cost 0.178857, Train acc 0.961030, test acc 0.938889, took 0.247 sec.
# Epoch 51: T.cost 0.176284, Train acc 0.962422, test acc 0.938889, took 0.192 sec.
# Epoch 52: T.cost 0.173636, Train acc 0.961030, test acc 0.938889, took 0.192 sec.
# Epoch 53: T.cost 0.169972, Train acc 0.962422, test acc 0.938889, took 0.199 sec.
# Epoch 54: T.cost 0.167006, Train acc 0.961030, test acc 0.938889, took 0.199 sec.
# Epoch 55: T.cost 0.163332, Train acc 0.963814, test acc 0.941667, took 0.272 sec.
# Epoch 56: T.cost 0.160588, Train acc 0.963814, test acc 0.941667, took 0.242 sec.
# Epoch 57: T.cost 0.157801, Train acc 0.966597, test acc 0.938889, took 0.237 sec.
# Epoch 58: T.cost 0.155215, Train acc 0.966597, test acc 0.936111, took 0.211 sec.
# New LR: 0.000729000050342
# Epoch 59: T.cost 0.152653, Train acc 0.965901, test acc 0.936111, took 0.253 sec.
# New Bin Sizes: [17, 17, 16, 17, 17]
# Epoch 60: T.cost 0.149971, Train acc 0.968685, test acc 0.936111, took 0.235 sec.
# Epoch 61: T.cost 0.147423, Train acc 0.969381, test acc 0.936111, took 0.187 sec.
# Epoch 62: T.cost 0.145817, Train acc 0.968685, test acc 0.936111, took 0.185 sec.
# Epoch 63: T.cost 0.143373, Train acc 0.968685, test acc 0.936111, took 0.184 sec.
# Epoch 64: T.cost 0.141831, Train acc 0.969381, test acc 0.936111, took 0.186 sec.
# Epoch 65: T.cost 0.139878, Train acc 0.970772, test acc 0.938889, took 0.184 sec.
# Epoch 66: T.cost 0.139088, Train acc 0.970772, test acc 0.938889, took 0.185 sec.
# Epoch 67: T.cost 0.136724, Train acc 0.972860, test acc 0.938889, took 0.184 sec.
# Epoch 68: T.cost 0.135051, Train acc 0.972860, test acc 0.938889, took 0.185 sec.
# Epoch 69: T.cost 0.133471, Train acc 0.972164, test acc 0.936111, took 0.185 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 70: T.cost 0.130954, Train acc 0.971468, test acc 0.936111, took 0.212 sec.
# Epoch 71: T.cost 0.130303, Train acc 0.970772, test acc 0.933333, took 0.184 sec.
# Epoch 72: T.cost 0.128491, Train acc 0.971468, test acc 0.936111, took 0.185 sec.
# Epoch 73: T.cost 0.127901, Train acc 0.971468, test acc 0.936111, took 0.184 sec.
# Epoch 74: T.cost 0.124860, Train acc 0.972164, test acc 0.938889, took 0.22 sec.
# Epoch 75: T.cost 0.124767, Train acc 0.970772, test acc 0.938889, took 0.249 sec.
# Epoch 76: T.cost 0.123461, Train acc 0.971468, test acc 0.938889, took 0.233 sec.
# Epoch 77: T.cost 0.122371, Train acc 0.971468, test acc 0.938889, took 0.209 sec.
# Epoch 78: T.cost 0.120578, Train acc 0.972860, test acc 0.936111, took 0.196 sec.
# New LR: 0.000656100071501
# Epoch 79: T.cost 0.119498, Train acc 0.972164, test acc 0.941667, took 0.254 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 80: T.cost 0.117034, Train acc 0.974252, test acc 0.944444, took 0.253 sec.
# Epoch 81: T.cost 0.115730, Train acc 0.974252, test acc 0.944444, took 0.187 sec.
# Epoch 82: T.cost 0.115309, Train acc 0.974252, test acc 0.944444, took 0.188 sec.
# Epoch 83: T.cost 0.113559, Train acc 0.974948, test acc 0.944444, took 0.187 sec.
# Epoch 84: T.cost 0.113230, Train acc 0.974948, test acc 0.944444, took 0.192 sec.
# Epoch 85: T.cost 0.112729, Train acc 0.974948, test acc 0.944444, took 0.188 sec.
# Epoch 86: T.cost 0.111494, Train acc 0.975644, test acc 0.941667, took 0.19 sec.
# Epoch 87: T.cost 0.110767, Train acc 0.977731, test acc 0.944444, took 0.187 sec.
# Epoch 88: T.cost 0.110009, Train acc 0.976340, test acc 0.947222, took 0.189 sec.
# Epoch 89: T.cost 0.110071, Train acc 0.976340, test acc 0.947222, took 0.279 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 90: T.cost 0.108812, Train acc 0.975644, test acc 0.944444, took 0.234 sec.
# Epoch 91: T.cost 0.108203, Train acc 0.976340, test acc 0.950000, took 0.187 sec.
# Epoch 92: T.cost 0.106204, Train acc 0.976340, test acc 0.947222, took 0.191 sec.
# Epoch 93: T.cost 0.105710, Train acc 0.977035, test acc 0.947222, took 0.225 sec.
# Epoch 94: T.cost 0.105864, Train acc 0.974948, test acc 0.947222, took 0.221 sec.
# Epoch 95: T.cost 0.103568, Train acc 0.977731, test acc 0.947222, took 0.187 sec.
# Epoch 96: T.cost 0.103162, Train acc 0.976340, test acc 0.947222, took 0.189 sec.
# Epoch 97: T.cost 0.102467, Train acc 0.977731, test acc 0.941667, took 0.186 sec.
# Epoch 98: T.cost 0.101428, Train acc 0.978427, test acc 0.941667, took 0.233 sec.
# New LR: 0.000590490043396
# Epoch 99: T.cost 0.100764, Train acc 0.977035, test acc 0.947222, took 0.24 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 100: T.cost 0.099881, Train acc 0.978427, test acc 0.941667, took 0.293 sec.
# Epoch 101: T.cost 0.099292, Train acc 0.977731, test acc 0.947222, took 0.248 sec.
# Epoch 102: T.cost 0.099130, Train acc 0.978427, test acc 0.947222, took 0.283 sec.
# Epoch 103: T.cost 0.097320, Train acc 0.979123, test acc 0.944444, took 0.248 sec.
# Epoch 104: T.cost 0.097425, Train acc 0.977731, test acc 0.944444, took 0.246 sec.
# Epoch 105: T.cost 0.096895, Train acc 0.979123, test acc 0.947222, took 0.211 sec.
# Epoch 106: T.cost 0.096574, Train acc 0.979819, test acc 0.947222, took 0.241 sec.
# Epoch 107: T.cost 0.095761, Train acc 0.979123, test acc 0.944444, took 0.22 sec.
# Epoch 108: T.cost 0.094452, Train acc 0.981211, test acc 0.950000, took 0.193 sec.
# Epoch 109: T.cost 0.094320, Train acc 0.979819, test acc 0.950000, took 0.195 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 110: T.cost 0.093856, Train acc 0.979819, test acc 0.947222, took 0.222 sec.
# Epoch 111: T.cost 0.093269, Train acc 0.980515, test acc 0.952778, took 0.254 sec.
# Epoch 112: T.cost 0.091529, Train acc 0.981211, test acc 0.952778, took 0.237 sec.
# Epoch 113: T.cost 0.090941, Train acc 0.981907, test acc 0.952778, took 0.236 sec.
# Epoch 114: T.cost 0.090656, Train acc 0.981907, test acc 0.952778, took 0.208 sec.
# Epoch 115: T.cost 0.090616, Train acc 0.979819, test acc 0.952778, took 0.187 sec.
# Epoch 116: T.cost 0.089915, Train acc 0.982603, test acc 0.955556, took 0.187 sec.
# Epoch 117: T.cost 0.088591, Train acc 0.981907, test acc 0.955556, took 0.187 sec.
# Epoch 118: T.cost 0.089099, Train acc 0.981211, test acc 0.955556, took 0.188 sec.
# New LR: 0.000531441054773
# Epoch 119: T.cost 0.088323, Train acc 0.982603, test acc 0.952778, took 0.187 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 120: T.cost 0.088738, Train acc 0.981211, test acc 0.955556, took 0.251 sec.
# Epoch 121: T.cost 0.087372, Train acc 0.983994, test acc 0.955556, took 0.25 sec.
# Epoch 122: T.cost 0.085812, Train acc 0.983299, test acc 0.952778, took 0.245 sec.
# Epoch 123: T.cost 0.086054, Train acc 0.983299, test acc 0.955556, took 0.246 sec.
# Epoch 124: T.cost 0.085033, Train acc 0.983994, test acc 0.955556, took 0.219 sec.
# Epoch 125: T.cost 0.084923, Train acc 0.983994, test acc 0.952778, took 0.194 sec.
# Epoch 126: T.cost 0.084401, Train acc 0.983994, test acc 0.955556, took 0.194 sec.
# Epoch 127: T.cost 0.084564, Train acc 0.983994, test acc 0.955556, took 0.194 sec.
# Epoch 128: T.cost 0.083874, Train acc 0.984690, test acc 0.955556, took 0.194 sec.
# Epoch 129: T.cost 0.084029, Train acc 0.983299, test acc 0.955556, took 0.192 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 130: T.cost 0.082204, Train acc 0.984690, test acc 0.955556, took 0.222 sec.
# Epoch 131: T.cost 0.082006, Train acc 0.984690, test acc 0.955556, took 0.192 sec.
# Epoch 132: T.cost 0.082374, Train acc 0.984690, test acc 0.955556, took 0.194 sec.
# Epoch 133: T.cost 0.080532, Train acc 0.984690, test acc 0.955556, took 0.191 sec.
# Epoch 134: T.cost 0.080343, Train acc 0.984690, test acc 0.955556, took 0.194 sec.
# Epoch 135: T.cost 0.079468, Train acc 0.985386, test acc 0.955556, took 0.268 sec.
# Epoch 136: T.cost 0.079595, Train acc 0.985386, test acc 0.955556, took 0.207 sec.
# Epoch 137: T.cost 0.078576, Train acc 0.986082, test acc 0.955556, took 0.193 sec.
# Epoch 138: T.cost 0.078271, Train acc 0.986082, test acc 0.955556, took 0.193 sec.
# New LR: 0.000478296959773
# Epoch 139: T.cost 0.077972, Train acc 0.985386, test acc 0.955556, took 0.22 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 140: T.cost 0.076836, Train acc 0.986778, test acc 0.955556, took 0.257 sec.
# Epoch 141: T.cost 0.076322, Train acc 0.987474, test acc 0.955556, took 0.193 sec.
# Epoch 142: T.cost 0.076015, Train acc 0.988170, test acc 0.955556, took 0.196 sec.
# Epoch 143: T.cost 0.075141, Train acc 0.986778, test acc 0.952778, took 0.192 sec.
# Epoch 144: T.cost 0.075036, Train acc 0.986778, test acc 0.955556, took 0.236 sec.
# Epoch 145: T.cost 0.074764, Train acc 0.986082, test acc 0.955556, took 0.235 sec.
# Epoch 146: T.cost 0.073502, Train acc 0.987474, test acc 0.955556, took 0.235 sec.
# Epoch 147: T.cost 0.073564, Train acc 0.988170, test acc 0.955556, took 0.192 sec.
# Epoch 148: T.cost 0.073844, Train acc 0.987474, test acc 0.955556, took 0.186 sec.
# Epoch 149: T.cost 0.072746, Train acc 0.986778, test acc 0.955556, took 0.186 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 150: T.cost 0.072626, Train acc 0.986778, test acc 0.955556, took 0.303 sec.
# Epoch 151: T.cost 0.072041, Train acc 0.986778, test acc 0.958333, took 0.25 sec.
# Epoch 152: T.cost 0.072138, Train acc 0.986082, test acc 0.958333, took 0.228 sec.
# Epoch 153: T.cost 0.071612, Train acc 0.986082, test acc 0.958333, took 0.27 sec.
# Epoch 154: T.cost 0.070588, Train acc 0.986778, test acc 0.955556, took 0.202 sec.
# Epoch 155: T.cost 0.070175, Train acc 0.986778, test acc 0.958333, took 0.193 sec.
# Epoch 156: T.cost 0.069636, Train acc 0.986082, test acc 0.955556, took 0.197 sec.
# Epoch 157: T.cost 0.069346, Train acc 0.986778, test acc 0.952778, took 0.202 sec.
# Epoch 158: T.cost 0.068906, Train acc 0.986082, test acc 0.952778, took 0.25 sec.
# New LR: 0.000430467253318
# Epoch 159: T.cost 0.068624, Train acc 0.988170, test acc 0.952778, took 0.249 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 160: T.cost 0.067318, Train acc 0.987474, test acc 0.952778, took 0.298 sec.
# Epoch 161: T.cost 0.066972, Train acc 0.988170, test acc 0.952778, took 0.269 sec.
# Epoch 162: T.cost 0.066544, Train acc 0.988170, test acc 0.952778, took 0.245 sec.
# Epoch 163: T.cost 0.066284, Train acc 0.988170, test acc 0.952778, took 0.241 sec.
# Epoch 164: T.cost 0.065687, Train acc 0.988170, test acc 0.952778, took 0.216 sec.
# Epoch 165: T.cost 0.064950, Train acc 0.988170, test acc 0.952778, took 0.195 sec.
# Epoch 166: T.cost 0.064283, Train acc 0.988170, test acc 0.952778, took 0.253 sec.
# Epoch 167: T.cost 0.064595, Train acc 0.987474, test acc 0.950000, took 0.236 sec.
# Epoch 168: T.cost 0.064417, Train acc 0.987474, test acc 0.952778, took 0.196 sec.
# Epoch 169: T.cost 0.063702, Train acc 0.987474, test acc 0.950000, took 0.195 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 170: T.cost 0.064014, Train acc 0.988866, test acc 0.950000, took 0.284 sec.
# Epoch 171: T.cost 0.062590, Train acc 0.987474, test acc 0.950000, took 0.206 sec.
# Epoch 172: T.cost 0.062569, Train acc 0.988170, test acc 0.952778, took 0.194 sec.
# Epoch 173: T.cost 0.061970, Train acc 0.988170, test acc 0.947222, took 0.196 sec.
# Epoch 174: T.cost 0.061672, Train acc 0.988170, test acc 0.947222, took 0.193 sec.
# Epoch 175: T.cost 0.061503, Train acc 0.988170, test acc 0.947222, took 0.244 sec.
# Epoch 176: T.cost 0.062194, Train acc 0.988170, test acc 0.947222, took 0.236 sec.
# Epoch 177: T.cost 0.061341, Train acc 0.987474, test acc 0.947222, took 0.198 sec.
# Epoch 178: T.cost 0.060728, Train acc 0.989562, test acc 0.947222, took 0.195 sec.
# New LR: 0.000387420522748
# Epoch 179: T.cost 0.060359, Train acc 0.989562, test acc 0.947222, took 0.194 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 180: T.cost 0.060979, Train acc 0.988170, test acc 0.947222, took 0.222 sec.
# Epoch 181: T.cost 0.060181, Train acc 0.989562, test acc 0.950000, took 0.194 sec.
# Epoch 182: T.cost 0.060291, Train acc 0.989562, test acc 0.947222, took 0.195 sec.
# Epoch 183: T.cost 0.059899, Train acc 0.989562, test acc 0.947222, took 0.193 sec.
# Epoch 184: T.cost 0.059529, Train acc 0.988866, test acc 0.944444, took 0.195 sec.
# Epoch 185: T.cost 0.059044, Train acc 0.988170, test acc 0.947222, took 0.199 sec.
# Epoch 186: T.cost 0.058613, Train acc 0.989562, test acc 0.947222, took 0.203 sec.
# Epoch 187: T.cost 0.058728, Train acc 0.988866, test acc 0.947222, took 0.196 sec.
# Epoch 188: T.cost 0.058660, Train acc 0.988866, test acc 0.944444, took 0.196 sec.
# Epoch 189: T.cost 0.058435, Train acc 0.988866, test acc 0.947222, took 0.195 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 190: T.cost 0.058120, Train acc 0.988170, test acc 0.944444, took 0.297 sec.
# Epoch 191: T.cost 0.057928, Train acc 0.988866, test acc 0.944444, took 0.253 sec.
# Epoch 192: T.cost 0.057618, Train acc 0.988170, test acc 0.941667, took 0.258 sec.
# Epoch 193: T.cost 0.057102, Train acc 0.989562, test acc 0.947222, took 0.269 sec.
# Epoch 194: T.cost 0.056577, Train acc 0.989562, test acc 0.941667, took 0.269 sec.
# Epoch 195: T.cost 0.055399, Train acc 0.990257, test acc 0.944444, took 0.256 sec.
# Epoch 196: T.cost 0.054863, Train acc 0.990257, test acc 0.938889, took 0.252 sec.
# Epoch 197: T.cost 0.055239, Train acc 0.990257, test acc 0.941667, took 0.241 sec.
# Epoch 198: T.cost 0.055065, Train acc 0.989562, test acc 0.941667, took 0.216 sec.
# New LR: 0.000348678475711
# Epoch 199: T.cost 0.054380, Train acc 0.990953, test acc 0.944444, took 0.195 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 200: T.cost 0.054660, Train acc 0.990257, test acc 0.944444, took 0.222 sec.
# Epoch 201: T.cost 0.053901, Train acc 0.990953, test acc 0.944444, took 0.195 sec.
# Epoch 202: T.cost 0.053598, Train acc 0.990953, test acc 0.944444, took 0.239 sec.
# Epoch 203: T.cost 0.053195, Train acc 0.990953, test acc 0.941667, took 0.237 sec.
# Epoch 204: T.cost 0.053217, Train acc 0.990953, test acc 0.944444, took 0.239 sec.
# Epoch 205: T.cost 0.053302, Train acc 0.990953, test acc 0.947222, took 0.199 sec.
# Epoch 206: T.cost 0.053206, Train acc 0.990953, test acc 0.947222, took 0.197 sec.
# Epoch 207: T.cost 0.053151, Train acc 0.990953, test acc 0.947222, took 0.195 sec.
# Epoch 208: T.cost 0.052022, Train acc 0.991649, test acc 0.947222, took 0.197 sec.
# Epoch 209: T.cost 0.052435, Train acc 0.990953, test acc 0.950000, took 0.196 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 210: T.cost 0.052167, Train acc 0.990953, test acc 0.950000, took 0.302 sec.
# Epoch 211: T.cost 0.051663, Train acc 0.991649, test acc 0.950000, took 0.246 sec.
# Epoch 212: T.cost 0.051978, Train acc 0.990953, test acc 0.952778, took 0.224 sec.
# Epoch 213: T.cost 0.051261, Train acc 0.991649, test acc 0.950000, took 0.199 sec.
# Epoch 214: T.cost 0.050974, Train acc 0.991649, test acc 0.952778, took 0.197 sec.
# Epoch 215: T.cost 0.051114, Train acc 0.991649, test acc 0.950000, took 0.195 sec.
# Epoch 216: T.cost 0.049835, Train acc 0.991649, test acc 0.950000, took 0.258 sec.
# Epoch 217: T.cost 0.050497, Train acc 0.991649, test acc 0.950000, took 0.245 sec.
# Epoch 218: T.cost 0.050797, Train acc 0.991649, test acc 0.947222, took 0.224 sec.
# New LR: 0.000313810622902
# Epoch 219: T.cost 0.050372, Train acc 0.990953, test acc 0.950000, took 0.188 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 220: T.cost 0.049129, Train acc 0.993041, test acc 0.947222, took 0.215 sec.
# Epoch 221: T.cost 0.049380, Train acc 0.990953, test acc 0.950000, took 0.188 sec.
# Epoch 222: T.cost 0.049440, Train acc 0.991649, test acc 0.947222, took 0.189 sec.
# Epoch 223: T.cost 0.048841, Train acc 0.991649, test acc 0.950000, took 0.188 sec.
# Epoch 224: T.cost 0.048730, Train acc 0.991649, test acc 0.950000, took 0.189 sec.
# Epoch 225: T.cost 0.048480, Train acc 0.992345, test acc 0.947222, took 0.311 sec.
# Epoch 226: T.cost 0.048005, Train acc 0.991649, test acc 0.950000, took 0.283 sec.
# Epoch 227: T.cost 0.048639, Train acc 0.991649, test acc 0.950000, took 0.258 sec.
# Epoch 228: T.cost 0.047169, Train acc 0.992345, test acc 0.947222, took 0.252 sec.
# Epoch 229: T.cost 0.047171, Train acc 0.991649, test acc 0.950000, took 0.287 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 230: T.cost 0.046771, Train acc 0.991649, test acc 0.950000, took 0.296 sec.
# Epoch 231: T.cost 0.047222, Train acc 0.991649, test acc 0.950000, took 0.255 sec.
# Epoch 232: T.cost 0.046404, Train acc 0.991649, test acc 0.950000, took 0.204 sec.
# Epoch 233: T.cost 0.046598, Train acc 0.991649, test acc 0.950000, took 0.277 sec.
# Epoch 234: T.cost 0.046161, Train acc 0.992345, test acc 0.950000, took 0.207 sec.
# Epoch 235: T.cost 0.046296, Train acc 0.991649, test acc 0.950000, took 0.196 sec.
# Epoch 236: T.cost 0.046331, Train acc 0.991649, test acc 0.950000, took 0.197 sec.
# Epoch 237: T.cost 0.045607, Train acc 0.991649, test acc 0.950000, took 0.24 sec.
# Epoch 238: T.cost 0.045688, Train acc 0.991649, test acc 0.950000, took 0.223 sec.
# New LR: 0.000282429563231
# Epoch 239: T.cost 0.045458, Train acc 0.991649, test acc 0.950000, took 0.201 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 240: T.cost 0.045084, Train acc 0.992345, test acc 0.950000, took 0.229 sec.
# Epoch 241: T.cost 0.045255, Train acc 0.991649, test acc 0.950000, took 0.195 sec.
# Epoch 242: T.cost 0.044858, Train acc 0.991649, test acc 0.950000, took 0.253 sec.
# Epoch 243: T.cost 0.045231, Train acc 0.991649, test acc 0.950000, took 0.256 sec.
# Epoch 244: T.cost 0.044167, Train acc 0.992345, test acc 0.950000, took 0.257 sec.
# Epoch 245: T.cost 0.043715, Train acc 0.992345, test acc 0.950000, took 0.25 sec.
# Epoch 246: T.cost 0.044523, Train acc 0.992345, test acc 0.950000, took 0.283 sec.
# Epoch 247: T.cost 0.044209, Train acc 0.992345, test acc 0.950000, took 0.248 sec.
# Epoch 248: T.cost 0.044952, Train acc 0.992345, test acc 0.950000, took 0.242 sec.
# Epoch 249: T.cost 0.043516, Train acc 0.993041, test acc 0.950000, took 0.216 sec.
# New Bin Sizes: [17, 17, 14, 17, 17]
# Epoch 250: T.cost 0.044704, Train acc 0.992345, test acc 0.950000, took 0.313 sec.
# Epoch 251: T.cost 0.043116, Train acc 0.993041, test acc 0.950000, took 0.196 sec.
# Epoch 252: T.cost 0.043398, Train acc 0.992345, test acc 0.950000, took 0.192 sec.
# Epoch 253: T.cost 0.043496, Train acc 0.992345, test acc 0.950000, took 0.197 sec.
# Epoch 254: T.cost 0.043412, Train acc 0.993041, test acc 0.950000, took 0.227 sec.
# Epoch 255: T.cost 0.043321, Train acc 0.993041, test acc 0.950000, took 0.234 sec.
# Epoch 256: T.cost 0.043142, Train acc 0.993737, test acc 0.950000, took 0.193 sec.
# Epoch 257: T.cost 0.042729, Train acc 0.993737, test acc 0.950000, took 0.192 sec.
# Epoch 258: T.cost 0.042415, Train acc 0.993041, test acc 0.950000, took 0.194 sec.
# New LR: 0.000254186609527
# Epoch 259: T.cost 0.041914, Train acc 0.994433, test acc 0.950000, took 0.241 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 260: T.cost 0.041678, Train acc 0.994433, test acc 0.950000, took 0.269 sec.
# Epoch 261: T.cost 0.041420, Train acc 0.994433, test acc 0.950000, took 0.194 sec.
# Epoch 262: T.cost 0.041142, Train acc 0.994433, test acc 0.950000, took 0.193 sec.
# Epoch 263: T.cost 0.041294, Train acc 0.994433, test acc 0.950000, took 0.191 sec.
# Epoch 264: T.cost 0.041153, Train acc 0.993737, test acc 0.950000, took 0.262 sec.
# Epoch 265: T.cost 0.041082, Train acc 0.994433, test acc 0.950000, took 0.258 sec.
# Epoch 266: T.cost 0.040759, Train acc 0.994433, test acc 0.950000, took 0.254 sec.
# Epoch 267: T.cost 0.040496, Train acc 0.994433, test acc 0.950000, took 0.252 sec.
# Epoch 268: T.cost 0.041060, Train acc 0.994433, test acc 0.950000, took 0.216 sec.
# Epoch 269: T.cost 0.040280, Train acc 0.993737, test acc 0.950000, took 0.197 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 270: T.cost 0.040271, Train acc 0.994433, test acc 0.950000, took 0.224 sec.
# Epoch 271: T.cost 0.040155, Train acc 0.994433, test acc 0.950000, took 0.197 sec.
# Epoch 272: T.cost 0.040471, Train acc 0.993737, test acc 0.950000, took 0.198 sec.
# Epoch 273: T.cost 0.039638, Train acc 0.995129, test acc 0.950000, took 0.197 sec.
# Epoch 274: T.cost 0.039706, Train acc 0.994433, test acc 0.950000, took 0.201 sec.
# Epoch 275: T.cost 0.040130, Train acc 0.994433, test acc 0.950000, took 0.198 sec.
# Epoch 276: T.cost 0.039614, Train acc 0.994433, test acc 0.950000, took 0.199 sec.
# Epoch 277: T.cost 0.039049, Train acc 0.994433, test acc 0.950000, took 0.222 sec.
# Epoch 278: T.cost 0.038985, Train acc 0.994433, test acc 0.950000, took 0.225 sec.
# New LR: 0.000228767938097
# Epoch 279: T.cost 0.039306, Train acc 0.994433, test acc 0.950000, took 0.197 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 280: T.cost 0.037828, Train acc 0.994433, test acc 0.950000, took 0.226 sec.
# Epoch 281: T.cost 0.037856, Train acc 0.995129, test acc 0.950000, took 0.197 sec.
# Epoch 282: T.cost 0.038029, Train acc 0.994433, test acc 0.950000, took 0.246 sec.
# Epoch 283: T.cost 0.037545, Train acc 0.994433, test acc 0.950000, took 0.244 sec.
# Epoch 284: T.cost 0.037963, Train acc 0.994433, test acc 0.950000, took 0.2 sec.
# Epoch 285: T.cost 0.037348, Train acc 0.995129, test acc 0.950000, took 0.198 sec.
# Epoch 286: T.cost 0.036487, Train acc 0.995129, test acc 0.950000, took 0.197 sec.
# Epoch 287: T.cost 0.037529, Train acc 0.995129, test acc 0.950000, took 0.258 sec.
# Epoch 288: T.cost 0.037045, Train acc 0.995129, test acc 0.950000, took 0.24 sec.
# Epoch 289: T.cost 0.036955, Train acc 0.995129, test acc 0.950000, took 0.23 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 290: T.cost 0.037288, Train acc 0.994433, test acc 0.950000, took 0.23 sec.
# Epoch 291: T.cost 0.036453, Train acc 0.995129, test acc 0.950000, took 0.198 sec.
# Epoch 292: T.cost 0.037121, Train acc 0.994433, test acc 0.950000, took 0.191 sec.
# Epoch 293: T.cost 0.036987, Train acc 0.994433, test acc 0.950000, took 0.19 sec.
# Epoch 294: T.cost 0.035821, Train acc 0.995129, test acc 0.950000, took 0.192 sec.
# Epoch 295: T.cost 0.035779, Train acc 0.995129, test acc 0.952778, took 0.19 sec.
# Epoch 296: T.cost 0.035554, Train acc 0.995129, test acc 0.952778, took 0.27 sec.
# Epoch 297: T.cost 0.035902, Train acc 0.995129, test acc 0.952778, took 0.279 sec.
# Epoch 298: T.cost 0.036503, Train acc 0.995129, test acc 0.952778, took 0.262 sec.
# New LR: 0.000205891144287
# Epoch 299: T.cost 0.036254, Train acc 0.995129, test acc 0.952778, took 0.252 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 300: T.cost 0.035074, Train acc 0.995129, test acc 0.952778, took 0.315 sec.
# Epoch 301: T.cost 0.034860, Train acc 0.995129, test acc 0.952778, took 0.202 sec.
# Epoch 302: T.cost 0.035246, Train acc 0.994433, test acc 0.952778, took 0.202 sec.
# Epoch 303: T.cost 0.034860, Train acc 0.995129, test acc 0.952778, took 0.2 sec.
# Epoch 304: T.cost 0.035110, Train acc 0.995129, test acc 0.952778, took 0.243 sec.
# Epoch 305: T.cost 0.034405, Train acc 0.995129, test acc 0.952778, took 0.245 sec.
# Epoch 306: T.cost 0.035467, Train acc 0.995129, test acc 0.952778, took 0.201 sec.
# Epoch 307: T.cost 0.034632, Train acc 0.995129, test acc 0.952778, took 0.199 sec.
# Epoch 308: T.cost 0.034936, Train acc 0.995129, test acc 0.952778, took 0.2 sec.
# Epoch 309: T.cost 0.034574, Train acc 0.995129, test acc 0.952778, took 0.271 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 310: T.cost 0.034129, Train acc 0.995129, test acc 0.952778, took 0.239 sec.
# Epoch 311: T.cost 0.034598, Train acc 0.995129, test acc 0.952778, took 0.199 sec.
# Epoch 312: T.cost 0.035084, Train acc 0.995129, test acc 0.952778, took 0.2 sec.
# Epoch 313: T.cost 0.034968, Train acc 0.995129, test acc 0.952778, took 0.247 sec.
# Epoch 314: T.cost 0.033920, Train acc 0.995129, test acc 0.952778, took 0.227 sec.
# Epoch 315: T.cost 0.034183, Train acc 0.995129, test acc 0.952778, took 0.198 sec.
# Epoch 316: T.cost 0.034102, Train acc 0.995129, test acc 0.952778, took 0.201 sec.
# Epoch 317: T.cost 0.033997, Train acc 0.995129, test acc 0.952778, took 0.2 sec.
# Epoch 318: T.cost 0.033465, Train acc 0.995129, test acc 0.950000, took 0.199 sec.
# New LR: 0.000185302033788
# Epoch 319: T.cost 0.033273, Train acc 0.995129, test acc 0.952778, took 0.201 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 320: T.cost 0.033297, Train acc 0.995129, test acc 0.952778, took 0.228 sec.
# Epoch 321: T.cost 0.032651, Train acc 0.995129, test acc 0.952778, took 0.199 sec.
# Epoch 322: T.cost 0.033573, Train acc 0.995129, test acc 0.952778, took 0.2 sec.
# Epoch 323: T.cost 0.033000, Train acc 0.995129, test acc 0.950000, took 0.277 sec.
# Epoch 324: T.cost 0.032918, Train acc 0.995129, test acc 0.952778, took 0.218 sec.
# Epoch 325: T.cost 0.032847, Train acc 0.995129, test acc 0.950000, took 0.203 sec.
# Epoch 326: T.cost 0.032509, Train acc 0.995129, test acc 0.952778, took 0.2 sec.
# Epoch 327: T.cost 0.033122, Train acc 0.995129, test acc 0.950000, took 0.241 sec.
# Epoch 328: T.cost 0.032729, Train acc 0.995129, test acc 0.952778, took 0.252 sec.
# Epoch 329: T.cost 0.033202, Train acc 0.995129, test acc 0.950000, took 0.202 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 330: T.cost 0.032449, Train acc 0.995129, test acc 0.952778, took 0.228 sec.
# Epoch 331: T.cost 0.032535, Train acc 0.995129, test acc 0.952778, took 0.21 sec.
# Epoch 332: T.cost 0.032258, Train acc 0.995129, test acc 0.950000, took 0.2 sec.
# Epoch 333: T.cost 0.032800, Train acc 0.995129, test acc 0.952778, took 0.202 sec.
# Epoch 334: T.cost 0.032472, Train acc 0.995129, test acc 0.950000, took 0.2 sec.
# Epoch 335: T.cost 0.032977, Train acc 0.995129, test acc 0.952778, took 0.203 sec.
# Epoch 336: T.cost 0.032791, Train acc 0.995129, test acc 0.950000, took 0.202 sec.
# Epoch 337: T.cost 0.032081, Train acc 0.995129, test acc 0.952778, took 0.2 sec.
# Epoch 338: T.cost 0.032180, Train acc 0.995129, test acc 0.950000, took 0.2 sec.
# New LR: 0.000166771833028
# Epoch 339: T.cost 0.033228, Train acc 0.995129, test acc 0.952778, took 0.203 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 340: T.cost 0.032238, Train acc 0.995129, test acc 0.950000, took 0.228 sec.
# Epoch 341: T.cost 0.032126, Train acc 0.995129, test acc 0.952778, took 0.227 sec.
# Epoch 342: T.cost 0.032236, Train acc 0.995129, test acc 0.950000, took 0.23 sec.
# Epoch 343: T.cost 0.031876, Train acc 0.995129, test acc 0.950000, took 0.199 sec.
# Epoch 344: T.cost 0.032511, Train acc 0.995129, test acc 0.950000, took 0.2 sec.
# Epoch 345: T.cost 0.031773, Train acc 0.995129, test acc 0.950000, took 0.201 sec.
# Epoch 346: T.cost 0.031869, Train acc 0.995129, test acc 0.950000, took 0.257 sec.
# Epoch 347: T.cost 0.031924, Train acc 0.995129, test acc 0.950000, took 0.216 sec.
# Epoch 348: T.cost 0.031726, Train acc 0.995129, test acc 0.950000, took 0.201 sec.
# Epoch 349: T.cost 0.032122, Train acc 0.995129, test acc 0.950000, took 0.2 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 350: T.cost 0.031507, Train acc 0.995129, test acc 0.950000, took 0.227 sec.
# Epoch 351: T.cost 0.032139, Train acc 0.995129, test acc 0.950000, took 0.266 sec.
# Epoch 352: T.cost 0.031885, Train acc 0.995129, test acc 0.950000, took 0.246 sec.
# Epoch 353: T.cost 0.031677, Train acc 0.995129, test acc 0.950000, took 0.227 sec.
# Epoch 354: T.cost 0.031222, Train acc 0.994433, test acc 0.950000, took 0.193 sec.
# Epoch 355: T.cost 0.031660, Train acc 0.995129, test acc 0.950000, took 0.198 sec.
# Epoch 356: T.cost 0.031215, Train acc 0.995129, test acc 0.950000, took 0.192 sec.
# Epoch 357: T.cost 0.031314, Train acc 0.995129, test acc 0.950000, took 0.194 sec.
# Epoch 358: T.cost 0.031144, Train acc 0.995129, test acc 0.950000, took 0.193 sec.
# New LR: 0.000150094648416
# Epoch 359: T.cost 0.030863, Train acc 0.995129, test acc 0.950000, took 0.194 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 360: T.cost 0.031068, Train acc 0.995129, test acc 0.950000, took 0.303 sec.
# Epoch 361: T.cost 0.030227, Train acc 0.995825, test acc 0.950000, took 0.192 sec.
# Epoch 362: T.cost 0.030336, Train acc 0.995825, test acc 0.950000, took 0.194 sec.
# Epoch 363: T.cost 0.030365, Train acc 0.994433, test acc 0.950000, took 0.193 sec.
# Epoch 364: T.cost 0.029600, Train acc 0.995825, test acc 0.950000, took 0.208 sec.
# Epoch 365: T.cost 0.029833, Train acc 0.995825, test acc 0.950000, took 0.26 sec.
# Epoch 366: T.cost 0.030256, Train acc 0.995825, test acc 0.950000, took 0.255 sec.
# Epoch 367: T.cost 0.029454, Train acc 0.995825, test acc 0.950000, took 0.235 sec.
# Epoch 368: T.cost 0.030012, Train acc 0.995825, test acc 0.950000, took 0.201 sec.
# Epoch 369: T.cost 0.029467, Train acc 0.995825, test acc 0.950000, took 0.276 sec.
# New Bin Sizes: [17, 17, 13, 17, 17]
# Epoch 370: T.cost 0.029553, Train acc 0.995825, test acc 0.950000, took 0.303 sec.
# Epoch 371: T.cost 0.030328, Train acc 0.995129, test acc 0.950000, took 0.258 sec.
# Epoch 372: T.cost 0.029468, Train acc 0.995825, test acc 0.950000, took 0.202 sec.
# Epoch 373: T.cost 0.029532, Train acc 0.995825, test acc 0.950000, took 0.288 sec.
# Epoch 374: T.cost 0.028704, Train acc 0.995825, test acc 0.950000, took 0.212 sec.
# Epoch 375: T.cost 0.029213, Train acc 0.995825, test acc 0.950000, took 0.201 sec.
# Epoch 376: T.cost 0.029690, Train acc 0.995825, test acc 0.950000, took 0.202 sec.
#
# Total time spent: 81.309 seconds
# Traing Acc: 0.995824634656
# Test Acc: 0.95

# %% [markdown]
# # HISTOGRAM

# %%
disc_output_r = disc_output.reshape((-1, QUANT_UNIT))
dense_output_r = param_output.reshape((-1, QUANT_UNIT))

plt.figure()
plt.plot(dense_output_r[:, 1], disc_output_r[:, 1], 'g.')

# %%
plt.figure(figsize=(8,8))
plt.semilogy(1-np.array(train_accs), label='Training Error')
plt.semilogy(1-np.array(test_accs), label='Test Error')
plt.legend(fontsize=20)
plt.xlabel('Epoch', fontsize=8)
plt.ylabel('Error', fontsize=8)
plt.grid(True)
plt.show()
